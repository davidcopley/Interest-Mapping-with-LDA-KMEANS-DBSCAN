# %%
import gensim

# %%
lda=gensim.models.ldamulticore.LdaMulticore.load("./ldaResult")

# %%
lda.show_topics(num_topics=100)
# Out:
# [(0,
#   '0.028*"process" + 0.020*"chemic" + 0.020*"offic" + 0.013*"combin" + 0.012*"mail" + 0.012*"file" + 0.012*"may" + 0.012*"system" + 0.012*"order" + 0.010*"use"'),
#  (1,
#   '0.026*"equip" + 0.020*"farm" + 0.019*"load" + 0.019*"duti" + 0.019*"sale" + 0.017*"oper" + 0.013*"machin" + 0.013*"build" + 0.013*"engin" + 0.013*"conveyor"'),
#  (2,
#   '0.026*"disord" + 0.021*"metal" + 0.021*"articl" + 0.017*"equip" + 0.015*"product" + 0.015*"famili" + 0.015*"photograph" + 0.015*"death" + 0.011*"treat" + 0.011*"system"'),
#  (3,
#   '0.022*"product" + 0.022*"materi" + 0.022*"harvest" + 0.018*"loan" + 0.018*"prune" + 0.018*"crop" + 0.018*"appli" + 0.015*"plant" + 0.013*"may" + 0.013*"book"'),
#  (4,
#   '0.035*"human" + 0.029*"clean" + 0.024*"research" + 0.024*"structur" + 0.018*"place" + 0.018*"may" + 0.018*"dentist" + 0.013*"specialist" + 0.012*"class" + 0.012*"educ"'),
#  (5,
# ...

# %%
lda.get_term_topics(10)
# Out:
# []
