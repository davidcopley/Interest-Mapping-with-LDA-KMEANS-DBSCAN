# %%
import numpy as np
import pandas as pd
import nltk
import re
import os
import codecs
import sklearn
import mpld3

# %%
df = pd.read_table("./careerData.txt")

# %%
df = df[['Title','Description']]

# %%
df.columns = ['title','description']
display(df)
# Out:
#                                                   title  \
# 0                                      Chief Executives
# 1                         Chief Sustainability Officers
# 2                       General and Operations Managers
# 3                                           Legislators
# 4                   Advertising and Promotions Managers
# 5                                       Green Marketers
# 6                                    Marketing Managers
# 7                                        Sales Managers
# 8             Public Relations and Fundraising Managers
# 9                      Administrative Services Managers
# 10            Computer and Information Systems Managers
# 11                                   Financial Managers
# 12                           Treasurers and Controllers
# 13             Financial Managers, Branch or Department
# 14                       Industrial Production Managers
# 15                     Quality Control Systems Managers
# 16                       Geothermal Production Managers
# 17                         Biofuels Production Managers
# 18                         Biomass Power Plant Managers
# 19     Methane/Landfill Gas Collection System Operators
# 20                    Hydroelectric Production Managers
# 21                                  Purchasing Managers
# 22    Transportation, Storage, and Distribution Mana...
# 23                              Transportation Managers
# 24                    Storage and Distribution Managers
# 25                                   Logistics Managers
# 26                   Compensation and Benefits Managers
# 27                             Human Resources Managers
# 28                    Training and Development Managers
# 29    Farmers, Ranchers, and Other Agricultural Mana...
# ...                                                 ...
# 1080  Laborers and Freight, Stock, and Material Move...
# 1081                     Machine Feeders and Offbearers
# 1082                        Packers and Packagers, Hand
# 1083   Gas Compressor and Gas Pumping Station Operators
# 1084            Pump Operators, Except Wellhead Pumpers
# 1085                                   Wellhead Pumpers
# 1086          Refuse and Recyclable Material Collectors
# 1087                         Mine Shuttle Car Operators
# 1088                  Tank Car, Truck, and Ship Loaders
# 1089                 Material Moving Workers, All Other
# 1090                                  Air Crew Officers
# 1091              Aircraft Launch and Recovery Officers
# 1092                   Armored Assault Vehicle Officers
# 1093                     Artillery and Missile Officers
# 1094                Command and Control Center Officers
# 1095                                  Infantry Officers
# 1096                            Special Forces Officers
# 1097  Military Officer Special and Tactical Operatio...
# 1098         First-Line Supervisors of Air Crew Members
# 1099  First-Line Supervisors of Weapons Specialists/...
# 1100  First-Line Supervisors of All Other Tactical O...
# 1101                                   Air Crew Members
# 1102           Aircraft Launch and Recovery Specialists
# 1103               Armored Assault Vehicle Crew Members
# 1104                 Artillery and Missile Crew Members
# 1105             Command and Control Center Specialists
# 1106                                           Infantry
# 1107                        Radar and Sonar Technicians
# 1108                                     Special Forces
# 1109  Military Enlisted Tactical Operations and Air/...
#
#                                             description
# 0     Determine and formulate policies and provide o...
# 1     Communicate and coordinate with management, sh...
# 2     Plan, direct, or coordinate the operations of ...
# 3     Develop, introduce or enact laws and statutes ...
# 4     Plan, direct, or coordinate advertising polici...
# 5     Create and implement methods to market green p...
# 6     Plan, direct, or coordinate marketing policies...
# 7     Plan, direct, or coordinate the actual distrib...
# 8     Plan, direct, or coordinate activities designe...
# 9     Plan, direct, or coordinate one or more admini...
# 10    Plan, direct, or coordinate activities in such...
# 11    Plan, direct, or coordinate accounting, invest...
# 12    Direct financial activities, such as planning,...
# 13    Direct and coordinate financial activities of ...
# 14    Plan, direct, or coordinate the work activitie...
# 15    Plan, direct, or coordinate quality assurance ...
# 16    Manage operations at geothermal power generati...
# 17    Manage biofuels production and plant operation...
# 18    Manage operations at biomass power generation ...
# 19    Direct daily operations, maintenance, or repai...
# 20    Manage operations at hydroelectric power gener...
# 21    Plan, direct, or coordinate the activities of ...
# 22    Plan, direct, or coordinate transportation, st...
# 23    Plan, direct, or coordinate the transportation...
# 24    Plan, direct, or coordinate the storage or dis...
# 25    Plan, direct, or coordinate purchasing, wareho...
# 26    Plan, direct, or coordinate compensation and b...
# 27    Plan, direct, or coordinate human resources ac...
# 28    Plan, direct, or coordinate the training and d...
# 29    Plan, direct, or coordinate the management or ...
# ...                                                 ...
# 1080  Manually move freight, stock, or other materia...
# 1081  Feed materials into or remove materials from m...
# 1082  Pack or package by hand a wide variety of prod...
# 1083  Operate steam, gas, electric motor, or interna...
# 1084  Tend, control, or operate power-driven, statio...
# 1085  Operate power pumps and auxiliary equipment to...
# 1086  Collect and dump refuse or recyclable material...
# 1087  Operate diesel or electric-powered shuttle car...
# 1088  Load and unload chemicals and bulk solids, suc...
# 1089  All material moving workers not listed separat...
# 1090  Perform and direct in-flight duties to ensure ...
# 1091  Plan and direct the operation and maintenance ...
# 1092  Direct the operation of tanks, light armor, an...
# 1093  Manage personnel and weapons operations to des...
# 1094  Manage the operation of communications, detect...
# 1095  Direct, train, and lead infantry units in grou...
# 1096  Lead elite teams that implement unconventional...
# 1097  All military officer special and tactical oper...
# 1098  Supervise and coordinate the activities of air...
# 1099  Supervise and coordinate the activities of wea...
# 1100  Supervise and coordinate the activities of all...
# 1101  Perform in-flight duties to ensure the success...
# 1102  Operate and maintain catapults, arresting gear...
# 1103  Operate tanks, light armor, and amphibious ass...
# 1104  Target, fire, and maintain weapons used to des...
# 1105  Operate and monitor communications, detection,...
# 1106  Operate weapons and equipment in ground combat...
# 1107  Operate equipment using radio or sound wave te...
# 1108  Implement unconventional operations by air, la...
# 1109  All military enlisted tactical operations and ...
#
# [1110 rows x 2 columns]

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
stemmer = nltk.stem.snowball.SnowballStemmer('english')

# %%
def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems

# %%
def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
totalvocab_stemmed = []
totalvocab_tokenized = []
for i in df['description'].values:
    allwords_stemmed = tokenize_and_stem(i) #for each item in 'synopses', tokenize/stem
    totalvocab_stemmed.extend(allwords_stemmed) #extend the 'totalvocab_stemmed' list
    
    allwords_tokenized = tokenize_only(i)
    totalvocab_tokenized.extend(allwords_tokenized)

# %%
vocab_frame = pd.DataFrame({'words': totalvocab_tokenized}, index = totalvocab_stemmed)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(
    max_features=200000,
    stop_words='english',
    use_idf=True, 
    tokenizer=tokenize_and_stem, 
    ngram_range=(1,3)
)

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(df['description'].values)

# %%
terms = tfidf_vectorizer.get_feature_names()

# %%
print(terms)
# Out:
# ["'s", "'s account", "'s account preparing", "'s appearance", "'s appearance includes", "'s assistants", "'s assistants hold", "'s blood", "'s blood stream", "'s budget", "'s budget policies", "'s cage", "'s cage desk", "'s credit", "'s credit application", "'s credit standing", "'s customers", "'s customers satisfied", "'s diseases", "'s diseases injuries", "'s hand", "'s hand players", "'s hand tools", "'s home", "'s home care", "'s internal", "'s internal composition", "'s liability", "'s liability concerning", "'s local", "'s local area", "'s numerical", "'s numerical coding", "'s physical", "'s physical emotional", "'s profits", "'s profits share", "'s request", "'s request use", "'s security", "'s security functions", "'s signature", "'s signature receipt", "'s specifications", "'s specifications compiling", "'s studies", "'s studies urban", "'s surface", "'s surface engineering", "'s surface includes", "'s surface relating", "'s surface using", "'s toys", "'s toys combine", "'s various", "'s various transactions", "'s vital", "'s vital signs", "'s wheel", "'s wheel process", "'s work", "'s work goals", "'s worth", "'s worth negotiate", 'abandoned', 'abandoned abused', 'abandoned abused children', 'abandoned dangerous', 'abandoned dangerous unattended', 'abating', 'abating eliminating', 'abating eliminating sources', 'abbreviations', 'abbreviations fully', 'abbreviations fully understandable', 'able', 'able seamen', 'able seamen ordinary', 'abnormalities', 'abnormalities determine', 'abnormalities determine cause', 'abnormalities pathological', 'abnormalities pathological conditions', 'aboard', 'aboard liquid-carrying', 'aboard liquid-carrying vessels', 'aboard ship', 'aboard ships', 'aboard ships boats', 'aboard ships buses', 'absences', 'absences sales', 'absences sales production', 'absorption', 'absorption studies', 'absorption studies following', 'abuse', 'abuse alcohol', 'abuse alcohol tobacco', 'abuse family', 'abuse family parenting', 'abuse human', 'abuse human relationships', 'abuse problems', 'abuse problems including', 'abused', 'abused children', 'abused children schools', 'abutments', 'abutments lay', 'abutments lay walks', 'academic', 'academic administrative', 'academic administrative auxiliary', 'academic functioning', 'academic functioning children', 'academic instruction', 'academic instruction students', 'academic life', 'academic life processes', 'academic nonacademic', 'academic nonacademic activities', 'academic social', 'academic social formative', 'accept', 'accept patron', "accept patron 's", 'accept payment', 'accept prescriptions', 'accept prescriptions filling', 'acceptance', 'acceptance applications', 'acceptance rejection', 'acceptance rejection claims', 'acceptance rejection credit', 'accepting', 'accepting delivering', 'accepting delivering securities', 'access', 'access healthcare', 'access information', 'accessing', 'accessing alphabetical', 'accessing alphabetical geographical', 'accessories', 'accessories bulldozer', 'accessories bulldozer blade', 'accessories collect', 'accessories collect payment', 'accessories create', 'accessories create original', 'accessories prospective', 'accessories prospective buyers', 'accessories windshield', 'accessories windshield wiper', 'accident', 'accident sickness', 'accident sickness disability', 'accidental', 'accidental violent', 'accidental violent unexplained', 'accidents', 'accidents apprehend', 'accidents apprehend arrest', 'accidents stress', 'accidents stress daily', 'accommodate', 'accommodate hotel', 'accommodate hotel motel', 'accommodations', 'accommodations required', 'accommodations required plan', 'accommodations travel', 'accommodations travel agency', 'accompaniment', 'accompaniment members', 'accompaniment members orchestra', 'accompany', 'accompany aircraft', 'accompany aircraft member', 'accompany clients', 'accompany clients property', 'accompany patients', 'accompany patients examinations', 'accordance', 'accordance company',  ...

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
dist = 1 - cosine_similarity(tfidf_matrix)

# %%
from sklearn.cluster import KMeans

# %%
num_clusters = 50
km = KMeans(n_clusters=num_clusters)

# %%
km.fit(tfidf_matrix)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=50, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
clusters = km.labels_.tolist()

# %%
df['cluster'] = clusters

# %%
df['cluster'].value_counts()
# Out:
# 15    53
# 43    50
# 26    48
# 31    43
# 12    36
# 41    35
# 40    35
# 8     34
# 3     33
# 25    32
# 44    32
# 29    30
# 9     28
# 16    26
# 30    26
# 34    26
# 45    24
# 4     24
# 20    23
# 47    23
# 13    22
# 27    22
# 46    22
# 21    22
# 23    21
# 49    21
# 33    20
# 37    20
# 18    19
# 2     19
# 24    19
# 48    18
# 0     17
# 38    17
# 28    16
# 14    15
# 6     15
# 10    14
# 17    14
# 36    13
# 42    13
# 35    11
# 11    11
# 32    11
# 5     10
# 19     8
# 1      7
# 39     6
# 22     5
# 7      1
# Name: cluster, dtype: int64

# %%
grouped1 = pd.DataFrame(df['title'].groupby(df['cluster']).agg("|".join))

# %%
grouped2 = pd.DataFrame(df['description'].groupby(df['cluster']).agg("|".join))

# %%
grouped = grouped1.join(grouped2)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.manifold import MDS

# %%
mds = MDS(n_components=2, dissimilarity="precomputed", random_state=1,n_jobs=-3)

# %%
pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

# %%
xs, ys = pos[:, 0], pos[:, 1]

# %%
# %matplotlib inline

# %%
df = pd.DataFrame(dict(x=xs, y=ys,label=clusters))

# %%
groups = df.groupby('label')

# %%
fig, ax = plt.subplots(figsize=(17, 17))

NUM_COLORS = num_clusters

cm = plt.get_cmap('gist_rainbow')
# ax.set_color_cycle([cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])
for name, group in groups:
    ax.plot(group.x, group.y, marker='o', linestyle='', ms=20, mec='none')
    ax.set_aspect('auto')
    ax.tick_params(\
        axis= 'x',          # changes apply to the x-axis
        which='both',      # both major and minor ticks are affected
        bottom='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelbottom='off')
    ax.tick_params(\
        axis= 'y',         # changes apply to the y-axis
        which='both',      # both major and minor ticks are affected
        left='off',      # ticks along the bottom edge are off
        top='off',         # ticks along the top edge are off
        labelleft='off')
    ax.legend(numpoints=1,labels=clusters)
for i in range(len(df)):
    ax.text(df.iloc[i]['x'], df.iloc[i]['y'], df.iloc[i]['label'], size=0)

# %%
text = "programming"
X = tfidf_vectorizer.transform(tokenize_and_stem(text))
print(grouped.iloc[km.predict(X)]['title'].values)
# Out:
# ['Cost Estimators|Logisticians|Logistics Analysts|Arbitrators, Mediators, and Conciliators|Health Specialties Teachers, Postsecondary|Self-Enrichment Education Teachers|Coaches and Scouts|Umpires, Referees, and Other Sports Officials|Dietetic Technicians|Medical Transcriptionists|Pharmacy Aides|Correctional Officers and Jailers|Chefs and Head Cooks|Cooks, Fast Food|Cooks, Private Household|Cooks, Restaurant|Cooks, Short Order|Bartenders|Baristas|Waiters and Waitresses|Dining Room and Cafeteria Attendants and Bartender Helpers|Hosts and Hostesses, Restaurant, Lounge, and Coffee Shop|Slot Supervisors|Counter and Rental Clerks|Retail Salespersons|Sales Representatives, Wholesale and Manufacturing, Except Technical and Scientific Products|Demonstrators and Product Promoters|Switchboard Operators, Including Answering Service|Procurement Clerks|Brokerage Clerks|Cargo and Freight Agents|Couriers and Messengers|Police, Fire, and Ambulance Dispatchers|Dispatchers, Except Police, Fire, and Ambulance|Postal Service Mail Carriers|Production, Planning, and Expediting Clerks|Shipping, Receiving, and Traffic Clerks|Stock Clerks and Order Fillers|Stock Clerks, Sales Floor|Stock Clerks- Stockroom, Warehouse, or Storage Yard|Order Fillers, Wholesale and Retail Sales|Pile-Driver Operators|Team Assemblers|Slaughterers and Meat Packers|Sewers, Hand|Aircraft Cargo Handling Supervisors|Commercial Pilots|Bus Drivers, Transit and Intercity|Driver/Sales Workers|Heavy and Tractor-Trailer Truck Drivers|Light Truck or Delivery Services Drivers|Taxi Drivers and Chauffeurs|Refuse and Recyclable Material Collectors']
