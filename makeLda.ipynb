# %%
import pandas as pd
import nltk

# %%
df = pd.read_table("./careerData.txt")
df = df [['Title','Description']]
df.columns=['title','desc']

# %%
display(df)
# Out:
#                                                   title  \
# 0                                      Chief Executives
# 1                         Chief Sustainability Officers
# 2                       General and Operations Managers
# 3                                           Legislators
# 4                   Advertising and Promotions Managers
# 5                                       Green Marketers
# 6                                    Marketing Managers
# 7                                        Sales Managers
# 8             Public Relations and Fundraising Managers
# 9                      Administrative Services Managers
# 10            Computer and Information Systems Managers
# 11                                   Financial Managers
# 12                           Treasurers and Controllers
# 13             Financial Managers, Branch or Department
# 14                       Industrial Production Managers
# 15                     Quality Control Systems Managers
# 16                       Geothermal Production Managers
# 17                         Biofuels Production Managers
# 18                         Biomass Power Plant Managers
# 19     Methane/Landfill Gas Collection System Operators
# 20                    Hydroelectric Production Managers
# 21                                  Purchasing Managers
# 22    Transportation, Storage, and Distribution Mana...
# 23                              Transportation Managers
# 24                    Storage and Distribution Managers
# 25                                   Logistics Managers
# 26                   Compensation and Benefits Managers
# 27                             Human Resources Managers
# 28                    Training and Development Managers
# 29    Farmers, Ranchers, and Other Agricultural Mana...
# ...                                                 ...
# 1080  Laborers and Freight, Stock, and Material Move...
# 1081                     Machine Feeders and Offbearers
# 1082                        Packers and Packagers, Hand
# 1083   Gas Compressor and Gas Pumping Station Operators
# 1084            Pump Operators, Except Wellhead Pumpers
# 1085                                   Wellhead Pumpers
# 1086          Refuse and Recyclable Material Collectors
# 1087                         Mine Shuttle Car Operators
# 1088                  Tank Car, Truck, and Ship Loaders
# 1089                 Material Moving Workers, All Other
# 1090                                  Air Crew Officers
# 1091              Aircraft Launch and Recovery Officers
# 1092                   Armored Assault Vehicle Officers
# 1093                     Artillery and Missile Officers
# 1094                Command and Control Center Officers
# 1095                                  Infantry Officers
# 1096                            Special Forces Officers
# 1097  Military Officer Special and Tactical Operatio...
# 1098         First-Line Supervisors of Air Crew Members
# 1099  First-Line Supervisors of Weapons Specialists/...
# 1100  First-Line Supervisors of All Other Tactical O...
# 1101                                   Air Crew Members
# 1102           Aircraft Launch and Recovery Specialists
# 1103               Armored Assault Vehicle Crew Members
# 1104                 Artillery and Missile Crew Members
# 1105             Command and Control Center Specialists
# 1106                                           Infantry
# 1107                        Radar and Sonar Technicians
# 1108                                     Special Forces
# 1109  Military Enlisted Tactical Operations and Air/...
#
#                                                    desc
# 0     Determine and formulate policies and provide o...
# 1     Communicate and coordinate with management, sh...
# 2     Plan, direct, or coordinate the operations of ...
# 3     Develop, introduce or enact laws and statutes ...
# 4     Plan, direct, or coordinate advertising polici...
# 5     Create and implement methods to market green p...
# 6     Plan, direct, or coordinate marketing policies...
# 7     Plan, direct, or coordinate the actual distrib...
# 8     Plan, direct, or coordinate activities designe...
# 9     Plan, direct, or coordinate one or more admini...
# 10    Plan, direct, or coordinate activities in such...
# 11    Plan, direct, or coordinate accounting, invest...
# 12    Direct financial activities, such as planning,...
# 13    Direct and coordinate financial activities of ...
# 14    Plan, direct, or coordinate the work activitie...
# 15    Plan, direct, or coordinate quality assurance ...
# 16    Manage operations at geothermal power generati...
# 17    Manage biofuels production and plant operation...
# 18    Manage operations at biomass power generation ...
# 19    Direct daily operations, maintenance, or repai...
# 20    Manage operations at hydroelectric power gener...
# 21    Plan, direct, or coordinate the activities of ...
# 22    Plan, direct, or coordinate transportation, st...
# 23    Plan, direct, or coordinate the transportation...
# 24    Plan, direct, or coordinate the storage or dis...
# 25    Plan, direct, or coordinate purchasing, wareho...
# 26    Plan, direct, or coordinate compensation and b...
# 27    Plan, direct, or coordinate human resources ac...
# 28    Plan, direct, or coordinate the training and d...
# 29    Plan, direct, or coordinate the management or ...
# ...                                                 ...
# 1080  Manually move freight, stock, or other materia...
# 1081  Feed materials into or remove materials from m...
# 1082  Pack or package by hand a wide variety of prod...
# 1083  Operate steam, gas, electric motor, or interna...
# 1084  Tend, control, or operate power-driven, statio...
# 1085  Operate power pumps and auxiliary equipment to...
# 1086  Collect and dump refuse or recyclable material...
# 1087  Operate diesel or electric-powered shuttle car...
# 1088  Load and unload chemicals and bulk solids, suc...
# 1089  All material moving workers not listed separat...
# 1090  Perform and direct in-flight duties to ensure ...
# 1091  Plan and direct the operation and maintenance ...
# 1092  Direct the operation of tanks, light armor, an...
# 1093  Manage personnel and weapons operations to des...
# 1094  Manage the operation of communications, detect...
# 1095  Direct, train, and lead infantry units in grou...
# 1096  Lead elite teams that implement unconventional...
# 1097  All military officer special and tactical oper...
# 1098  Supervise and coordinate the activities of air...
# 1099  Supervise and coordinate the activities of wea...
# 1100  Supervise and coordinate the activities of all...
# 1101  Perform in-flight duties to ensure the success...
# 1102  Operate and maintain catapults, arresting gear...
# 1103  Operate tanks, light armor, and amphibious ass...
# 1104  Target, fire, and maintain weapons used to des...
# 1105  Operate and monitor communications, detection,...
# 1106  Operate weapons and equipment in ground combat...
# 1107  Operate equipment using radio or sound wave te...
# 1108  Implement unconventional operations by air, la...
# 1109  All military enlisted tactical operations and ...
#
# [1110 rows x 2 columns]

# %%
#strip any proper names from a text...unfortunately right now this is yanking the first word from a sentence too.
import string
def strip_proppers(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent) if word.islower()]
    return "".join([" "+i if not i.startswith("'") and i not in string.punctuation else i for i in tokens]).strip()

# %%
#strip any proper nouns (NNP) or plural proper nouns (NNPS) from a text
from nltk.tag import pos_tag

def strip_proppers_POS(text):
    tagged = pos_tag(text.split()) #use NLTK's part of speech tagger
    non_propernouns = [word for word,pos in tagged if pos != 'NNP' and pos != 'NNPS']
    return non_propernouns

# %%
# here I define a tokenizer and stemmer which returns the set of stems in the text that it is passed

def tokenize_and_stem(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    stems = [stemmer.stem(t) for t in filtered_tokens]
    return stems


def tokenize_only(text):
    # first tokenize by sentence, then by word to ensure that punctuation is caught as it's own token
    tokens = [word.lower() for sent in nltk.sent_tokenize(text) for word in nltk.word_tokenize(sent)]
    filtered_tokens = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        if re.search('[a-zA-Z]', token):
            filtered_tokens.append(token)
    return filtered_tokens

# %%
from gensim import corpora, models, similarities 
import re
from nltk.stem.snowball import SnowballStemmer
# load nltk's English stopwords as variable called 'stopwords'
stopwords = nltk.corpus.stopwords.words('english')
stemmer = SnowballStemmer("english")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
#remove proper names
# %time preprocess = [strip_proppers(doc) for doc in df['desc']]

#tokenize
# %time tokenized_text = [tokenize_and_stem(text) for text in preprocess]

#remove stop words
# %time texts = [[word for word in text if word not in stopwords] for text in tokenized_text]
# Out:
# Wall time: 397 ms
# Wall time: 627 ms
# Wall time: 52 ms

# %%
display(texts)
# Out:
# [['formul',
#   'polici',
#   'provid',
#   'overal',
#   'direct',
#   'compani',
#   'privat',
#   'public',
#   'sector',
#   'organ',
#   'within',
#   'guidelin',
#   'set',
#   'board',
#   'director',
#   'similar',
#   'govern',
#   'bodi',
#   'direct',
#   'coordin',
#   'oper',
#   'activ',
#   'highest',
#   'level',
#   'manag',
#   'help',
#   'subordin',
#   'execut',
#   'staff',
#   'manag'],
#  ['coordin',
#   'manag',
#   'sharehold',
#   'custom',
#   'employe',
#   'address',
#   'sustain',
#   'issu',
#   'overse',
#   'corpor',
#   'sustain',
#   'strategi'],
#  ['direct',
#   'coordin',
#   'oper',
#   'public',
#   'privat',
#   'sector',
#   'organ',
#   'respons',
#   'includ',
#   'formul',
#   'polici',
#   'manag',
#   'daili',
#   'oper',
#   'plan',
#   'use',
#   'materi',
#   'human',
#   'resourc',
#   'divers',
#   'general',
#   'natur',
#   'classifi',
#   'ani',
#   'one',
#   'function',
#   'area',
#   'manag',
#   'administr',
#   'personnel',
#   'purchas',
#   'administr',
#   'servic'],
#  ['introduc',
#   'enact',
#   'law',
#   'statut',
#   'local',
#   'tribal',
#   'level',
#   'onli',
#   'worker',
#   'elect',
#   'posit'],
#  ['direct',
#   'coordin',
#   'advertis',
#   'polici',
#   'program',
#   'produc',
#   'collater',
#   'materi',
#   'poster',
#   'contest',
#   'coupon',
#   'give-away',
#   'creat',
#   'extra',
#   'interest',
#   'purchas',
#   'product',
#   'servic',
#   'depart',
#   'entir',
#   'organ',
#   'account',
#   'basi'],
#  ['implement', 'method', 'market', 'green', 'product', 'servic'],
#  ['direct',
#   'coordin',
#   'market',
#   'polici',
#   'program',
#   'determin',
#   'demand',
#   'product',
#   'servic',
#   'offer',
#   'firm',
#   'competitor',
#   'identifi',
#   'potenti',
#   'custom',
#   'price',
#   'strategi',
#   'goal',
#   'maxim',
#   'firm',
#   "'s",
#   'profit',
#   'share',
#   'market',
#   'ensur',
#   'firm',
#   "'s",
#   'custom',
#   'satisfi',
#   'product',
#   'develop',
#   'monitor',
#   'trend',
#   'indic',
#   'need',
#   'new',
#   'product',
#   'servic'],
#  ['direct',
#   'coordin',
#   'actual',
#   'distribut',
#   'movement',
#   'product',
#   'servic',
#   'custom',
#   'sale',
#   'distribut',
#   'establish',
#   'sale',
#   'territori',
#   'quota',
#   'goal',
#   'establish',
#   'train',
#   'program',
#   'sale',
#   'repres',
#   'sale',
#   'statist',
#   'gather',
#   'staff',
#   'determin',
#   'sale',
#   'potenti',
#   'inventori',
#   'requir',
#   'monitor',
#   'prefer',
#   'custom'],
#  ['direct',
#   'coordin',
#   'activ',
#   'design',
#   'creat',
#   'maintain',
#   'favor',
#   'public',
#   'imag',
#   'rais',
#   'issu',
#   'awar',
#   'organ',
#   'client',
#   'engag',
#   'fundrais',
#   'plan',
#   'direct',
#   'coordin',
#   'activ',
#   'solicit',
#   'maintain',
#   'fund',
#   'special',
#   'project',
#   'nonprofit',
#   'organ'],
#  ['direct',
#   'coordin',
#   'one',
#   'administr',
#   'servic',
#   'organ',
#   'record',
#   'inform',
#   'manag',
#   'mail',
#   'distribut',
#   'facil',
#   'plan',
#   'mainten',
#   'custodi',
#   'oper',
#   'offic',
#   'support',
#   'servic'],
#  ['direct',
#   'coordin',
#   'activ',
#   'field',
#   'electron',
#   'data',
#   'process',
#   'inform',
#   'system',
#   'system',
#   'analysi',
#   'comput',
#   'program'],
#  ['direct',
#   'coordin',
#   'account',
#   'invest',
#   'bank',
#   'insur',
#   'secur',
#   'financi',
#   'activ',
#   'branch',
#   'offic',
#   'depart',
#   'establish'],
#  ['financi', 'activ', 'plan', 'procur', 'invest', 'part', 'organ'],
#  ['coordin',
#   'financi',
#   'activ',
#   'worker',
#   'branch',
#   'offic',
#   'depart',
#   'establish',
#   'branch',
#   'bank',
#   'brokerag',
#   'firm',
#   'risk',
#   'insur',
#   'depart',
#   'credit',
#   'depart'],
#  ['direct',
#   'coordin',
#   'work',
#   'activ',
#   'resourc',
#   'necessari',
#   'manufactur',
#   'product',
#   'accord',
#   'cost',
#   'qualiti',
#   'quantiti',
#   'specif'],
#  ['direct',
#   'coordin',
#   'qualiti',
#   'assur',
#   'program',
#   'qualiti',
#   'control',
#   'polici',
#   'control',
#   'qualiti',
#   'laboratori',
#   'product',
#   'effort'],
#  ['oper',
#   'geotherm',
#   'power',
#   'generat',
#   'facil',
#   'monitor',
#   'geotherm',
#   'plant',
#   'equip',
#   'effici',
#   'safe',
#   'plant',
#   'oper'],
#  ['biofuel',
#   'product',
#   'plant',
#   'oper',
#   'process',
#   'inform',
#   'plant',
#   'product',
#   'perform',
#   'diagnos',
#   'problem',
#   'design',
#   'correct',
#   'procedur'],
#  ['oper',
#   'biomass',
#   'power',
#   'generat',
#   'facil',
#   'work',
#   'activ',
#   'plant',
#   'includ',
#   'supervis',
#   'oper',
#   'mainten',
#   'staff'],
#  ['daili',
#   'oper',
#   'mainten',
#   'repair',
#   'landfil',
#   'gas',
#   'project',
#   'includ',
#   'mainten',
#   'daili',
#   'log',
#   'determin',
#   'servic',
#   'prioriti',
#   'complianc',
#   'report',
#   'requir'],
#  ['oper',
#   'hydroelectr',
#   'power',
#   'generat',
#   'facil',
#   'monitor',
#   'hydroelectr',
#   'plant',
#   'equip',
#   'effici',
#   'safe',
#   'plant',
#   'oper'],
#  ['direct',
#   'coordin',
#   'activ',
#   'buyer',
#   'purchas',
#   'offic',
#   'relat',
#   'worker',
#   'involv',
#   'purchas',
#   'materi',
#   'product',
#   'servic',
#   'wholesal',
#   'retail',
#   'trade',
#   'merchandis',
#   'manag',
#   'procur',
#   'manag'],
#  ['direct',
#   'coordin',
#   'transport',
#   'storag',
#   'distribut',
#   'activ',
#   'accord',
#   'organiz',
#   'polici',
#   'applic',
#   'govern',
#   'law',
#   'regul',
#   'logist',
#   'manag'],
#  ['direct',
#   'coordin',
#   'transport',
#   'oper',
#   'within',
#   'organ',
#   'activ',
#   'organ',
#   'provid',
#   'transport',
#   'servic'],
#  ['direct',
#   'coordin',
#   'storag',
#   'distribut',
#   'oper',
#   'within',
#   'organ',
#   'activ',
#   'organ',
#   'engag',
#   'store',
#   'distribut',
#   'materi',
#   'product'],
#  ['direct',
#   'coordin',
#   'purchas',
#   'wareh',
#   'distribut',
#   'forecast',
#   'custom',
#   'servic',
#   'plan',
#   'servic',
#   'logist',
#   'personnel',
#   'logist',
#   'system',
#   'direct',
#   'daili',
#   'oper'],
#  ['direct', 'coordin', 'compens', 'benefit', 'activ', 'organ'],
#  ['direct', 'coordin', 'human', 'resourc', 'activ', 'staff', 'organ'],
#  ['direct', 'coordin', 'train', 'develop', 'activ', 'staff', 'organ'],
#  ['direct',
#   'coordin',
#   'manag',
#   'oper',
#   'farm',
#   'ranch',
#   'greenhous',
#   'aquacultur',
#   'oper',
#   'nurseri',
#   'timber',
#   'tract',
#   'agricultur',
#   'establish',
#   'hire',
#   'train',
#   'supervis',
#   'farm',
#   'worker',
#   'contract',
#   'servic',
#   'carri',
#   'day-to-day',
#   'activ',
#   'manag',
#   'oper',
#   'engag',
#   'supervis',
#   'plant',
#   'cultiv',
#   'harvest',
#   'financi',
#   'market',
#   'activ'],
#  ['organ',
#   'direct',
#   'control',
#   'coordin',
#   'activ',
#   'worker',
#   'engag',
#   'propag',
#   'cultiv',
#   'harvest',
#   'horticultur',
#   'specialti',
#   'tree',
#   'shrub',
#   'flower',
#   'mushroom',
#   'plant'],
#  ['direct',
#   'coordin',
#   'manag',
#   'oper',
#   'farm',
#   'ranch',
#   'greenhous',
#   'aquacultur',
#   'oper',
#   'nurseri',
#   'timber',
#   'tract',
#   'agricultur',
#   'establish',
#   'hire',
#   'train',
#   'supervis',
#   'farm',
#   'worker',
#   'contract',
#   'servic',
#   'carri',
#   'day-to-day',
#   'activ',
#   'manag',
#   'oper',
#   'engag',
#   'supervis',
#   'plant',
#   'cultiv',
#   'harvest',
#   'financi',
#   'market',
#   'activ'],
#  ['coordin',
#   'subordin',
#   'supervisori',
#   'personnel',
#   'activ',
#   'worker',
#   'engag',
#   'fish',
#   'hatcheri',
#   'product',
#   'corpor',
#   'cooper',
#   'owner'],
#  ['direct',
#   'coordin',
#   'usual',
#   'subordin',
#   'supervisori',
#   'personnel',
#   'activ',
#   'concern',
#   'construct',
#   'mainten',
#   'structur',
#   'facil',
#   'system',
#   'conceptu',
#   'develop',
#   'construct',
#   'project',
#   'overse',
#   'organ',
#   'schedul',
#   'budget',
#   'implement',
#   'manag',
#   'special',
#   'construct',
#   'field',
#   'carpentri',
#   'plumb'],
#  ['direct',
#   'coordin',
#   'academ',
#   'nonacadem',
#   'activ',
#   'preschool',
#   'childcar',
#   'center',
#   'program'],
#  ['direct',
#   'coordin',
#   'academ',
#   'administr',
#   'auxiliari',
#   'activ',
#   'public',
#   'privat',
#   'elementari',
#   'secondari',
#   'level',
#   'school'],
#  ['direct',
#   'coordin',
#   'research',
#   'instruct',
#   'student',
#   'administr',
#   'servic',
#   'educ',
#   'activ',
#   'postsecondari',
#   'institut',
#   'includ',
#   'univers',
#   'colleg',
#   'junior',
#   'communiti',
#   'colleg'],
#  ['educ', 'administr', 'list', 'separ'],
#  ['day-to-day', 'oper', 'distanc', 'learn', 'program', 'schedul', 'cours'],
#  ['coordin',
#   'fit',
#   'well',
#   'program',
#   'servic',
#   'train',
#   'staff',
#   'well',
#   'specialist',
#   'health',
#   'educ',
#   'fit',
#   'instructor'],
#  ['direct',
#   'coordin',
#   'activ',
#   'field',
#   'architectur',
#   'engin',
#   'research',
#   'develop',
#   'field'],
#  ['plan',
#   'execut',
#   'biofuels/biodiesel',
#   'research',
#   'program',
#   'evalu',
#   'altern',
#   'feedstock',
#   'process',
#   'technolog',
#   'near-term',
#   'commerci',
#   'potenti'],
#  ['direct', 'coordin', 'activ', 'organ', 'depart', 'serv', 'food', 'beverag'],
#  ['direct',
#   'coordin',
#   'servic',
#   'resourc',
#   'funer',
#   'home',
#   'activ',
#   'determin',
#   'price',
#   'servic',
#   'merchandis',
#   'manag',
#   'facil',
#   'funer',
#   'home'],
#  ['direct', 'coordin', 'game', 'oper', 'casino', 'formul', 'hous', 'rule'],
#  ['direct',
#   'coordin',
#   'activ',
#   'organ',
#   'depart',
#   'provid',
#   'lodg',
#   'accommod'],
#  ['direct',
#   'coordin',
#   'medic',
#   'health',
#   'servic',
#   'hospit',
#   'clinic',
#   'manag',
#   'care',
#   'organ',
#   'public',
#   'health',
#   'agenc',
#   'similar',
#   'organ'],
#  ['direct',
#   'coordin',
#   'activ',
#   'field',
#   'life',
#   'scienc',
#   'physic',
#   'scienc',
#   'mathemat',
#   'statist',
#   'research',
#   'develop',
#   'field'],
#  ['direct',
#   'coordin',
#   'clinic',
#   'research',
#   'project',
#   'activ',
#   'worker',
#   'engag',
#   'clinic',
#   'research',
#   'project',
#   'ensur',
#   'complianc',
#   'protocol',
#   'overal',
#   'clinic',
#   'object',
#   'evalu',
#   'analyz',
#   'clinic',
#   'data'],
#  ['implement',
#   'program',
#   'strategi',
#   'relat',
#   'water',
#   'resourc',
#   'issu',
#   'suppli',
#   'qualiti',
#   'regulatori',
#   'complianc',
#   'issu'],
#  ['direct',
#   'coordin',
#   'oper',
#   'administr',
#   'manag',
#   'support',
#   'servic',
#   'post',
#   'offic',
#   'coordin',
#   'activ',
#   'worker',
#   'engag',
#   'postal',
#   'relat',
#   'work',
#   'assign',
#   'post',
#   'offic'],
#  ['direct',
#   'coordin',
#   'sell',
#   'buy',
#   'leas',
#   'govern',
#   'activ',
#   'commerci',
#   'industri',
#   'residenti',
#   'real',
#   'estat',
#   'properti',
#   'manag',
#   'homeown',
#   'condominium',
#   'associ',
#   'rent',
#   'leas',
#   'hous',
#   'unit',
#   'build',
#   'land',
#   'includ',
#   'rights-of-way'],
#  ['direct',
#   'coordin',
#   'activ',
#   'social',
#   'servic',
#   'program',
#   'communiti',
#   'outreach',
#   'organ',
#   'program',
#   'organ',
#   "'s",
#   'budget',
#   'polici',
#   'regard',
#   'particip',
#   'involv',
#   'program',
#   'requir',
#   'benefit',
#   'may',
#   'involv',
#   'direct',
#   'social',
#   'worker',
#   'counselor',
#   'probat',
#   'offic'],
#  ['direct',
#   'disast',
#   'respons',
#   'crisi',
#   'manag',
#   'activ',
#   'provid',
#   'disast',
#   'prepared',
#   'train',
#   'prepar',
#   'emerg',
#   'plan',
#   'procedur',
#   'natur',
#   'e.g',
#   'hurrican',
#   'flood',
#   'earthquak',
#   'wartim',
#   'technolog',
#   'e.g',
#   'nuclear',
#   'power',
#   'plant',
#   'emerg',
#   'hazard',
#   'materi',
#   'spill',
#   'disast',
#   'hostag',
#   'situat'],
#  ['manag', 'list', 'separ'],
#  ['direct',
#   'coordin',
#   'product',
#   'activ',
#   'organ',
#   'ensur',
#   'complianc',
#   'regul',
#   'standard',
#   'oper',
#   'procedur'],
#  ['direct',
#   'coordin',
#   'activ',
#   'organ',
#   'ensur',
#   'complianc',
#   'ethic',
#   'regulatori',
#   'standard'],
#  ['direct',
#   'coordin',
#   'invest',
#   'strategi',
#   'oper',
#   'larg',
#   'pool',
#   'liquid',
#   'asset',
#   'suppli',
#   'institut',
#   'investor',
#   'individu',
#   'investor'],
#  ['coordin',
#   'product',
#   'purchas',
#   'wareh',
#   'distribut',
#   'financi',
#   'forecast',
#   'servic',
#   'activ',
#   'limit',
#   'cost',
#   'improv',
#   'accuraci',
#   'custom',
#   'servic',
#   'safeti',
#   'exist',
#   'procedur',
#   'opportun',
#   'streamlin',
#   'activ',
#   'meet',
#   'product',
#   'distribut',
#   'need',
#   'movement',
#   'storag',
#   'process',
#   'inventori'],
#  ['organ',
#   "'s",
#   'secur',
#   'function',
#   'includ',
#   'physic',
#   'secur',
#   'safeti',
#   'employe',
#   'facil',
#   'asset'],
#  ['direct',
#   'polici',
#   'procedur',
#   'system',
#   'prevent',
#   'loss',
#   'asset',
#   'risk',
#   'exposur',
#   'potenti',
#   'liabil',
#   'develop',
#   'risk',
#   'control',
#   'measur'],
#  ['wind',
#   'field',
#   'oper',
#   'includ',
#   'personnel',
#   'mainten',
#   'activ',
#   'financi',
#   'activ',
#   'plan'],
#  ['manag',
#   'develop',
#   'evalu',
#   'potenti',
#   'wind',
#   'energi',
#   'busi',
#   'opportun',
#   'includ',
#   'environment',
#   'studi',
#   'permit',
#   'propos',
#   'also',
#   'manag',
#   'construct',
#   'project'],
#  ['direct',
#   'cleanup',
#   'redevelop',
#   'contamin',
#   'properti',
#   'reus',
#   'includ',
#   'properti',
#   'suffici',
#   'contamin',
#   'qualifi',
#   'site'],
#  ['promot',
#   'artist',
#   'perform',
#   'athlet',
#   'deal',
#   'current',
#   'prospect',
#   'employ',
#   'handl',
#   'contract',
#   'negoti',
#   'busi',
#   'matter',
#   'client'],
#  ['farm',
#   'product',
#   'either',
#   'process',
#   'resal',
#   'tree',
#   'farm',
#   'contractor',
#   'grain',
#   'broker',
#   'market',
#   'oper',
#   'grain',
#   'buyer',
#   'tobacco',
#   'buyer'],
#  ['merchandis',
#   'commod',
#   'farm',
#   'product',
#   'resal',
#   'consum',
#   'wholesal',
#   'retail',
#   'level',
#   'includ',
#   'durabl',
#   'nondur',
#   'good',
#   'past',
#   'buy',
#   'trend',
#   'sale',
#   'record',
#   'price',
#   'qualiti',
#   'merchandis',
#   'determin',
#   'valu',
#   'yield',
#   'order',
#   'author',
#   'payment',
#   'merchandis',
#   'accord',
#   'contractu',
#   'agreement',
#   'conduct',
#   'meet',
#   'sale',
#   'personnel',
#   'introduc',
#   'new',
#   'product',
#   'assist',
#   'wholesal',
#   'retail',
#   'buyer',
#   'nonfarm',
#   'product'],
#  ['machineri',
#   'equip',
#   'tool',
#   'part',
#   'suppli',
#   'servic',
#   'necessari',
#   'oper',
#   'establish',
#   'raw',
#   'semi-finish',
#   'materi',
#   'manufactur'],
#  ['settl',
#   'claim',
#   'determin',
#   'payment',
#   'settlement',
#   'made',
#   'accord',
#   'compani',
#   'practic',
#   'procedur',
#   'legal',
#   'counsel',
#   'claim',
#   'requir',
#   'litig',
#   'also',
#   'settl',
#   'insur',
#   'claim'],
#  ['settl',
#   'insur',
#   'claim',
#   'determin',
#   'payment',
#   'settlement',
#   'made',
#   'accord',
#   'compani',
#   'practic',
#   'procedur',
#   'overpay',
#   'underpay',
#   'irregular',
#   'legal',
#   'counsel',
#   'claim',
#   'requir',
#   'litig'],
#  ['analyz',
#   'determin',
#   'extent',
#   'insur',
#   'compani',
#   "'s",
#   'liabil',
#   'concern',
#   'person',
#   'casualti',
#   'properti',
#   'loss',
#   'damag',
#   'attempt',
#   'effect',
#   'settlement',
#   'claimant',
#   'interview',
#   'medic',
#   'specialist',
#   'agent',
#   'wit',
#   'claimant',
#   'compil',
#   'inform',
#   'benefit',
#   'payment',
#   'approv',
#   'payment',
#   'claim',
#   'within',
#   'certain',
#   'monetari',
#   'limit'],
#  ['automobil',
#   'vehicl',
#   'damag',
#   'determin',
#   'repair',
#   'cost',
#   'insur',
#   'claim',
#   'settlement',
#   'insur',
#   'form',
#   'indic',
#   'repair',
#   'cost',
#   'cost',
#   'estim',
#   'recommend',
#   'seek',
#   'agreement',
#   'automot',
#   'repair',
#   'shop',
#   'repair',
#   'cost'],
#  ['evalu',
#   'investig',
#   'elig',
#   'conform',
#   'law',
#   'regul',
#   'govern',
#   'contract',
#   'complianc',
#   'licens',
#   'permit',
#   'perform',
#   'complianc',
#   'enforc',
#   'inspect',
#   'analysi',
#   'activ',
#   'classifi',
#   'elsewher'],
#  ['investig',
#   'sourc',
#   'pollut',
#   'protect',
#   'public',
#   'environ',
#   'ensur',
#   'conform',
#   'local',
#   'regul',
#   'ordin'],
#  ['evalu', 'investig', 'elig', 'conform', 'liabil', 'licens', 'permit'],
#  ['evalu',
#   'complianc',
#   'equal',
#   'opportun',
#   'law',
#   'guidelin',
#   'polici',
#   'ensur',
#   'employ',
#   'practic',
#   'contract',
#   'arrang',
#   'give',
#   'equal',
#   'opportun',
#   'without',
#   'regard',
#   'race',
#   'religion',
#   'color',
#   'nation',
#   'origin',
#   'sex',
#   'age',
#   'disabl'],
#  ['inspect',
#   'govern',
#   'properti',
#   'ensur',
#   'complianc',
#   'contract',
#   'agreement',
#   'govern',
#   'regul'],
#  ['activ',
#   'autopsi',
#   'patholog',
#   'toxicolog',
#   'analys',
#   'inquest',
#   'relat',
#   'investig',
#   'death',
#   'occur',
#   'within',
#   'legal',
#   'jurisdict',
#   'determin',
#   'caus',
#   'death',
#   'fix',
#   'respons',
#   'accident',
#   'violent',
#   'unexplain',
#   'death'],
#  ['document',
#   'intern',
#   'regulatori',
#   'process',
#   'intern',
#   'audit',
#   'inspect',
#   'licens',
#   'renew',
#   'registr',
#   'compil',
#   'prepar',
#   'materi',
#   'submiss',
#   'regulatori',
#   'agenc'],
#  ['cost',
#   'estim',
#   'product',
#   'manufactur',
#   'construct',
#   'project',
#   'servic',
#   'aid',
#   'manag',
#   'bid',
#   'determin',
#   'price',
#   'product',
#   'servic',
#   'special',
#   'accord',
#   'particular',
#   'servic',
#   'perform',
#   'type',
#   'product',
#   'manufactur'],
#  ['activ',
#   'human',
#   'resourc',
#   'area',
#   'employ',
#   'specialist',
#   'screen',
#   'recruit',
#   'interview',
#   'place',
#   'worker'],
#  ['hire',
#   'season',
#   'temporari',
#   'agricultur',
#   'labor',
#   'transport',
#   'hous',
#   'provid',
#   'meal',
#   'worker'],
#  ['disput',
#   'worker',
#   'manag',
#   'negoti',
#   'collect',
#   'bargain',
#   'agreement',
#   'coordin',
#   'grievanc',
#   'procedur',
#   'handl',
#   'employe',
#   'complaint'],
#  ['coordin',
#   'logist',
#   'function',
#   'firm',
#   'organ',
#   'entir',
#   'life',
#   'cycl',
#   'product',
#   'includ',
#   'acquisit',
#   'distribut',
#   'intern',
#   'alloc',
#   'deliveri',
#   'final',
#   'dispos',
#   'resourc'],
#  ['analyz',
#   'oper',
#   'solut',
#   'project',
#   'transport',
#   'optim',
#   'network',
#   'model',
#   'process',
#   'method',
#   'analysi',
#   'cost',
#   'contain',
#   'capac',
#   'enhanc',
#   'rout',
#   'shipment',
#   'optim',
#   'inform',
#   'manag'],
#  ['product',
#   'deliveri',
#   'suppli',
#   'chain',
#   'process',
#   'identifi',
#   'recommend',
#   'chang',
#   'manag',
#   'rout',
#   'activ',
#   'includ',
#   'invoic',
#   'electron',
#   'bill',
#   'shipment',
#   'trace'],
#  ['organiz',
#   'studi',
#   'evalu',
#   'design',
#   'system',
#   'procedur',
#   'conduct',
#   'work',
#   'simplif',
#   'measur',
#   'studi',
#   'prepar',
#   'oper',
#   'procedur',
#   'manual',
#   'assist',
#   'manag',
#   'oper',
#   'effici',
#   'effect',
#   'program',
#   'analyst',
#   'manag',
#   'consult'],
#  ['activ',
#   'staff',
#   'convent',
#   'personnel',
#   'client',
#   'make',
#   'arrang',
#   'group',
#   'meet',
#   'event',
#   'convent'],
#  ['activ',
#   'rais',
#   'fund',
#   'otherwis',
#   'solicit',
#   'gather',
#   'monetari',
#   'donat',
#   'gift',
#   'organ',
#   'design',
#   'produc',
#   'promot',
#   'materi',
#   'also',
#   'rais',
#   'awar',
#   'organ',
#   "'s",
#   'work',
#   'goal',
#   'financi',
#   'need'],
#  ['program',
#   'compens',
#   'benefit',
#   'job',
#   'analysi',
#   'employ',
#   'special',
#   'specif',
#   'area',
#   'posit',
#   'classif',
#   'pension',
#   'program'],
#  ['conduct',
#   'train',
#   'develop',
#   'program',
#   'improv',
#   'individu',
#   'organiz',
#   'perform',
#   'analyz',
#   'train',
#   'need'],
#  ['market',
#   'condit',
#   'local',
#   'region',
#   'nation',
#   'area',
#   'gather',
#   'inform',
#   'determin',
#   'potenti',
#   'sale',
#   'product',
#   'servic',
#   'creat',
#   'market',
#   'campaign',
#   'gather',
#   'inform',
#   'competitor',
#   'price',
#   'sale',
#   'method',
#   'market',
#   'distribut'],
#  ['busi', 'oper', 'specialist', 'list', 'separ'],
#  ['energi',
#   'audit',
#   'build',
#   'build',
#   'system',
#   'process',
#   'system',
#   'also',
#   'conduct',
#   'invest',
#   'grade',
#   'audit',
#   'build',
#   'system'],
#  ['secur',
#   'assess',
#   'organ',
#   'design',
#   'secur',
#   'system',
#   'process',
#   'special',
#   'area',
#   'physic',
#   'secur',
#   'personnel',
#   'secur',
#   'inform',
#   'secur',
#   'work',
#   'field',
#   'health',
#   'care',
#   'bank',
#   'game',
#   'secur',
#   'engin',
#   'manufactur'],
#  ['custom',
#   'document',
#   'ensur',
#   'shipment',
#   'meet',
#   'applic',
#   'law',
#   'facilit',
#   'import',
#   'export',
#   'good',
#   'track',
#   'duti',
#   'tax',
#   'payabl',
#   'process',
#   'payment',
#   'behalf',
#   'client',
#   'document',
#   'power',
#   'attorney',
#   'client',
#   'meet',
#   'custom',
#   'offici',
#   'appli',
#   'duti',
#   'refund',
#   'tariff',
#   'reclassif',
#   'transport',
#   'storag',
#   'import',
#   'good'],
#  ['maintain',
#   'implement',
#   'busi',
#   'continu',
#   'disast',
#   'recoveri',
#   'strategi',
#   'solut',
#   'includ',
#   'risk',
#   'assess',
#   'busi',
#   'impact',
#   'analys',
#   'strategi',
#   'select',
#   'document',
#   'busi',
#   'continu',
#   'disast',
#   'recoveri',
#   'procedur',
#   'conduct',
#   'debrief',
#   'regular',
#   'mock-disast',
#   'exercis',
#   'test',
#   'adequaci',
#   'exist',
#   'plan',
#   'strategi',
#   'updat',
#   'procedur',
#   'plan',
#   'regular',
#   'coordin',
#   'continu',
#   'effort',
#   'disrupt',
#   'event'],
#  ['organiz',
#   'sustain',
#   'issu',
#   'wast',
#   'stream',
#   'manag',
#   'green',
#   'build',
#   'practic',
#   'green',
#   'procur',
#   'plan'],
#  ['retail',
#   'activ',
#   'busi',
#   'oper',
#   'exclus',
#   'onlin',
#   'perform',
#   'duti',
#   'prepar',
#   'busi',
#   'strategi',
#   'buy',
#   'merchandis',
#   'manag',
#   'inventori',
#   'implement',
#   'market',
#   'activ',
#   'fulfil',
#   'ship',
#   'onlin',
#   'order',
#   'balanc',
#   'financi',
#   'record'],
#  ['analyz',
#   'interpret',
#   'account',
#   'record',
#   'prepar',
#   'financi',
#   'statement',
#   'give',
#   'advic',
#   'audit',
#   'evalu',
#   'statement',
#   'prepar',
#   'advis',
#   'system',
#   'record',
#   'cost',
#   'financi',
#   'budgetari',
#   'data'],
#  ['financi',
#   'inform',
#   'prepar',
#   'financi',
#   'report',
#   'determin',
#   'maintain',
#   'record',
#   'asset',
#   'liabil',
#   'profit',
#   'loss',
#   'tax',
#   'liabil',
#   'financi',
#   'activ',
#   'within',
#   'organ'],
#  ['analyz',
#   'account',
#   'record',
#   'determin',
#   'financi',
#   'status',
#   'establish',
#   'prepar',
#   'financi',
#   'report',
#   'concern',
#   'oper',
#   'procedur'],
#  ['real',
#   'properti',
#   'estim',
#   'fair',
#   'valu',
#   'assess',
#   'tax',
#   'accord',
#   'prescrib',
#   'schedul'],
#  ['real',
#   'person',
#   'properti',
#   'determin',
#   'fair',
#   'valu',
#   'assess',
#   'tax',
#   'accord',
#   'prescrib',
#   'schedul'],
#  ['real',
#   'properti',
#   'determin',
#   'valu',
#   'purchas',
#   'sale',
#   'invest',
#   'mortgag',
#   'loan',
#   'purpos'],
#  ['budget',
#   'estim',
#   'complet',
#   'accuraci',
#   'conform',
#   'procedur',
#   'regul',
#   'budget',
#   'account',
#   'report'],
#  ['credit',
#   'data',
#   'financi',
#   'statement',
#   'individu',
#   'firm',
#   'determin',
#   'degre',
#   'risk',
#   'involv',
#   'extend',
#   'credit',
#   'lend',
#   'money',
#   'report',
#   'credit',
#   'inform',
#   'use',
#   'decis',
#   'make'],
#  ['quantit',
#   'analys',
#   'inform',
#   'affect',
#   'invest',
#   'program',
#   'public',
#   'privat',
#   'institut'],
#  ['client',
#   'financi',
#   'plan',
#   'use',
#   'knowledg',
#   'tax',
#   'invest',
#   'strategi',
#   'secur',
#   'insur',
#   'pension',
#   'plan',
#   'real',
#   'estat',
#   'includ',
#   'assess',
#   'client',
#   'asset',
#   'liabil',
#   'cash',
#   'flow',
#   'insur',
#   'coverag',
#   'tax',
#   'status',
#   'financi',
#   'object'],
#  ['individu',
#   'applic',
#   'insur',
#   'evalu',
#   'degre',
#   'risk',
#   'involv',
#   'determin',
#   'accept',
#   'applic'],
#  ['ensur',
#   'complianc',
#   'law',
#   'regul',
#   'govern',
#   'financi',
#   'secur',
#   'institut',
#   'financi',
#   'real',
#   'estat',
#   'transact',
#   'examin',
#   'verifi',
#   'authent',
#   'record'],
#  ['educ',
#   'individu',
#   'organ',
#   'acquir',
#   'manag',
#   'debt',
#   'provid',
#   'guidanc',
#   'determin',
#   'best',
#   'type',
#   'loan',
#   'explain',
#   'loan',
#   'requir',
#   'restrict',
#   'help',
#   'develop',
#   'debt',
#   'manag',
#   'plan',
#   'advis',
#   'credit',
#   'issu',
#   'provid',
#   'budget',
#   'mortgag',
#   'bankruptci',
#   'counsel'],
#  ['guidanc',
#   'prospect',
#   'loan',
#   'applic',
#   'problem',
#   'qualifi',
#   'tradit',
#   'loan',
#   'may',
#   'includ',
#   'determin',
#   'best',
#   'type',
#   'loan',
#   'explain',
#   'loan',
#   'requir',
#   'restrict'],
#  ['author',
#   'recommend',
#   'approv',
#   'commerci',
#   'real',
#   'estat',
#   'credit',
#   'loan',
#   'borrow',
#   'financi',
#   'status',
#   'payment',
#   'method',
#   'mortgag',
#   'loan',
#   'offic',
#   'agent',
#   'collect',
#   'analyst',
#   'loan',
#   'servic',
#   'offic',
#   'loan',
#   'underwrit'],
#  ['tax',
#   'liabil',
#   'collect',
#   'tax',
#   'individu',
#   'busi',
#   'firm',
#   'accord',
#   'prescrib',
#   'law',
#   'regul'],
#  ['tax', 'return', 'individu', 'small', 'busi'],
#  ['financi', 'specialist', 'list', 'separ'],
#  ['quantit',
#   'financi',
#   'product',
#   'use',
#   'inform',
#   'individu',
#   'financi',
#   'institut',
#   'engag',
#   'save',
#   'lend',
#   'invest',
#   'borrow',
#   'manag',
#   'risk',
#   'method',
#   'financi',
#   'analysi',
#   'creat',
#   'mathemat',
#   'model',
#   'use',
#   'develop',
#   'improv',
#   'analyt',
#   'tool',
#   'advanc',
#   'financi',
#   'invest',
#   'instrument'],
#  ['manag',
#   'risk',
#   'manag',
#   'issu',
#   'identifi',
#   'measur',
#   'make',
#   'decis',
#   'oper',
#   'enterpris',
#   'risk',
#   'organ'],
#  ['communic',
#   'negoti',
#   'corpor',
#   'issuer',
#   'secur',
#   'client',
#   'regard',
#   'privat',
#   'equiti',
#   'invest',
#   'issuanc',
#   'secur',
#   'provid',
#   'capit',
#   'client',
#   'growth',
#   'structur',
#   'term',
#   'merger',
#   'acquisit'],
#  ['evid',
#   'take',
#   'statement',
#   'produc',
#   'report',
#   'testifi',
#   'find',
#   'regard',
#   'resolut',
#   'fraud',
#   'alleg',
#   'coordin',
#   'fraud',
#   'detect',
#   'prevent',
#   'activ'],
#  ['research',
#   'fundament',
#   'comput',
#   'inform',
#   'scienc',
#   'theorist',
#   'design',
#   'inventor',
#   'solut',
#   'problem',
#   'field',
#   'comput',
#   'hardwar',
#   'softwar'],
#  ['scienc',
#   'engin',
#   'busi',
#   'data',
#   'process',
#   'problem',
#   'implement',
#   'improv',
#   'comput',
#   'system',
#   'user',
#   'requir',
#   'procedur',
#   'problem',
#   'autom',
#   'improv',
#   'exist',
#   'system',
#   'review',
#   'comput',
#   'system',
#   'capabl',
#   'workflow',
#   'schedul',
#   'limit',
#   'analyz',
#   'recommend',
#   'commerci',
#   'avail',
#   'softwar'],
#  ['knowledg',
#   'nurs',
#   'informat',
#   'assist',
#   'design',
#   'develop',
#   'ongo',
#   'modif',
#   'computer',
#   'health',
#   'care',
#   'system',
#   'educ',
#   'staff',
#   'assist',
#   'problem',
#   'solv',
#   'promot',
#   'implement',
#   'health',
#   'care',
#   'system'],
#  ['implement',
#   'upgrad',
#   'monitor',
#   'secur',
#   'measur',
#   'protect',
#   'comput',
#   'network',
#   'inform',
#   'ensur',
#   'appropri',
#   'secur',
#   'control',
#   'place',
#   'safeguard',
#   'digit',
#   'file',
#   'vital',
#   'electron',
#   'infrastructur',
#   'respond',
#   'comput',
#   'secur',
#   'breach',
#   'virus'],
#  ['modifi',
#   'test',
#   'code',
#   'form',
#   'script',
#   'allow',
#   'comput',
#   'applic',
#   'run',
#   'specif',
#   'drawn',
#   'softwar',
#   'develop',
#   'individu',
#   'assist',
#   'softwar',
#   'develop',
#   'analyz',
#   'user',
#   'need',
#   'design',
#   'softwar',
#   'solut',
#   'develop',
#   'write',
#   'comput',
#   'program',
#   'store',
#   'locat',
#   'retriev',
#   'specif',
#   'document',
#   'data',
#   'inform'],
#  ['creat',
#   'modifi',
#   'general',
#   'comput',
#   'applic',
#   'softwar',
#   'special',
#   'util',
#   'program',
#   'user',
#   'need',
#   'develop',
#   'softwar',
#   'solut',
#   'softwar',
#   'custom',
#   'softwar',
#   'client',
#   'use',
#   'aim',
#   'optim',
#   'oper',
#   'effici',
#   'analyz',
#   'design',
#   'databas',
#   'within',
#   'applic',
#   'area',
#   'work',
#   'individu',
#   'coordin',
#   'databas',
#   'develop',
#   'part',
#   'team',
#   'supervis',
#   'comput',
#   'programm'],
#  ['design',
#   'develop',
#   'test',
#   'oper',
#   'systems-level',
#   'softwar',
#   'compil',
#   'network',
#   'distribut',
#   'softwar',
#   'medic',
#   'industri',
#   'militari',
#   'communic',
#   'aerospac',
#   'busi',
#   'scientif',
#   'general',
#   'comput',
#   'applic',
#   'oper',
#   'specif',
#   'formul',
#   'analyz',
#   'softwar',
#   'requir',
#   'design',
#   'embed',
#   'system',
#   'softwar',
#   'principl',
#   'techniqu',
#   'comput',
#   'scienc',
#   'engin',
#   'mathemat',
#   'analysi'],
#  ['creat',
#   'modifi',
#   'site',
#   'user',
#   'need',
#   'implement',
#   'site',
#   'content',
#   'graphic',
#   'perform',
#   'capac',
#   'integr',
#   'site',
#   'comput',
#   'applic',
#   'convert',
#   'written',
#   'graphic',
#   'audio',
#   'video',
#   'compon',
#   'compat',
#   'format',
#   'use',
#   'softwar',
#   'design',
#   'facilit',
#   'creation',
#   'multimedia',
#   'content'],
#  ['test',
#   'implement',
#   'comput',
#   'databas',
#   'appli',
#   'knowledg',
#   'databas',
#   'manag',
#   'system',
#   'chang',
#   'comput',
#   'databas',
#   'plan',
#   'coordin',
#   'implement',
#   'secur',
#   'measur',
#   'safeguard',
#   'comput',
#   'databas'],
#  ['configur',
#   'support',
#   'organ',
#   "'s",
#   'local',
#   'area',
#   'network',
#   'wide',
#   'area',
#   'network',
#   'system',
#   'segment',
#   'network',
#   'system',
#   'network',
#   'ensur',
#   'network',
#   'avail',
#   'system',
#   'user',
#   'may',
#   'perform',
#   'necessari',
#   'mainten',
#   'support',
#   'network',
#   'avail',
#   'monitor',
#   'test',
#   'site',
#   'perform',
#   'ensur',
#   'site',
#   'oper',
#   'correct',
#   'without',
#   'interrupt',
#   'assist',
#   'network',
#   'model',
#   'analysi',
#   'plan',
#   'coordin',
#   'network',
#   'data',
#   'communic',
#   'hardwar',
#   'softwar',
#   'supervis',
#   'comput',
#   'user',
#   'support',
#   'specialist',
#   'comput',
#   'network',
#   'support',
#   'specialist',
#   'administ',
#   'network',
#   'secur',
#   'measur'],
#  ['implement',
#   'comput',
#   'inform',
#   'network',
#   'local',
#   'area',
#   'network',
#   'wide',
#   'area',
#   'network',
#   'intranet',
#   'extranet',
#   'data',
#   'communic',
#   'network',
#   'network',
#   'model',
#   'analysi',
#   'plan',
#   'also',
#   'design',
#   'network',
#   'comput',
#   'secur',
#   'measur',
#   'research',
#   'recommend',
#   'network',
#   'data',
#   'communic',
#   'hardwar',
#   'softwar'],
#  ['configur',
#   'voic',
#   'video',
#   'data',
#   'communic',
#   'system',
#   'instal',
#   'post-instal',
#   'servic',
#   'mainten'],
#  ['technic',
#   'assist',
#   'comput',
#   'user',
#   'question',
#   'resolv',
#   'comput',
#   'problem',
#   'client',
#   'person',
#   'via',
#   'telephon',
#   'electron',
#   'provid',
#   'assist',
#   'concern',
#   'use',
#   'comput',
#   'hardwar',
#   'softwar',
#   'includ',
#   'print',
#   'instal',
#   'word',
#   'process',
#   'electron',
#   'mail',
#   'oper',
#   'system'],
#  ['test',
#   'troubleshoot',
#   'evalu',
#   'exist',
#   'network',
#   'system',
#   'local',
#   'area',
#   'network',
#   'wide',
#   'area',
#   'network',
#   'system',
#   'segment',
#   'network',
#   'system',
#   'network',
#   'mainten',
#   'ensur',
#   'network',
#   'oper',
#   'correct',
#   'minim',
#   'interrupt'],
#  ['comput', 'occup', 'list', 'separ'],
#  ['execut',
#   'softwar',
#   'test',
#   'plan',
#   'order',
#   'identifi',
#   'softwar',
#   'problem',
#   'caus'],
#  ['develop',
#   'solut',
#   'complex',
#   'applic',
#   'problem',
#   'system',
#   'administr',
#   'issu',
#   'network',
#   'concern',
#   'system',
#   'manag',
#   'integr',
#   'function'],
#  ['web',
#   'environ',
#   'design',
#   'deploy',
#   'develop',
#   'mainten',
#   'activ',
#   'test',
#   'qualiti',
#   'assur',
#   'web',
#   'site',
#   'web',
#   'applic'],
#  ['develop',
#   'geospati',
#   'technolog',
#   'produc',
#   'databas',
#   'perform',
#   'applic',
#   'program',
#   'coordin',
#   'project',
#   'special',
#   'area',
#   'agricultur',
#   'mine',
#   'health',
#   'care',
#   'retail',
#   'trade',
#   'urban',
#   'plan',
#   'militari',
#   'intellig'],
#  ['scientist',
#   'technologist',
#   'relat',
#   'profession',
#   'build',
#   'maintain',
#   'modifi',
#   'use',
#   'geograph',
#   'inform',
#   'system',
#   'databas',
#   'also',
#   'perform',
#   'custom',
#   'applic',
#   'develop',
#   'provid',
#   'user',
#   'support'],
#  ['strategi',
#   'enterpris',
#   'databas',
#   'system',
#   'set',
#   'standard',
#   'oper',
#   'program',
#   'secur',
#   'construct',
#   'larg',
#   'relat',
#   'databas',
#   'new',
#   'system',
#   'exist',
#   'warehous',
#   'structur',
#   'refin',
#   'system',
#   'perform',
#   'function'],
#  ['model',
#   'implement',
#   'corpor',
#   'data',
#   'wareh',
#   'activ',
#   'configur',
#   'warehous',
#   'databas',
#   'inform',
#   'provid',
#   'support',
#   'warehous',
#   'user'],
#  ['financi',
#   'market',
#   'intellig',
#   'queri',
#   'data',
#   'repositori',
#   'generat',
#   'period',
#   'report',
#   'method',
#   'identifi',
#   'data',
#   'pattern',
#   'trend',
#   'avail',
#   'inform',
#   'sourc'],
#  ['initi',
#   'manag',
#   'inform',
#   'technolog',
#   'project',
#   'guid',
#   'work',
#   'technic',
#   'staff',
#   'liaison',
#   'busi',
#   'technic',
#   'aspect',
#   'project',
#   'project',
#   'stage',
#   'assess',
#   'busi',
#   'implic',
#   'stage',
#   'progress',
#   'assur',
#   'deadlin',
#   'standard',
#   'cost',
#   'target',
#   'met'],
#  ['search',
#   'market',
#   'tactic',
#   'increas',
#   'visibl',
#   'engag',
#   'content',
#   'product',
#   'servic',
#   'devic',
#   'interfac',
#   'search',
#   'queri',
#   'behavior',
#   'general',
#   'specialti',
#   'search',
#   'engin',
#   'content',
#   'research',
#   'data',
#   'technolog',
#   'understand',
#   'user',
#   'intent',
#   'measur',
#   'outcom',
#   'ongo',
#   'optim'],
#  ['core',
#   'featur',
#   'video',
#   'game',
#   'innov',
#   'game',
#   'role-play',
#   'mechan',
#   'stori',
#   'line',
#   'charact',
#   'biographi',
#   'maintain',
#   'design',
#   'document',
#   'collabor',
#   'product',
#   'staff',
#   'produc',
#   'game',
#   'design'],
#  ['administ',
#   'enterprise-wid',
#   'document',
#   'manag',
#   'system',
#   'relat',
#   'procedur',
#   'allow',
#   'organ',
#   'captur',
#   'store',
#   'retriev',
#   'share',
#   'destroy',
#   'electron',
#   'record',
#   'document'],
#  ['statist',
#   'data',
#   'mortal',
#   'accid',
#   'sick',
#   'disabl',
#   'retir',
#   'rate',
#   'construct',
#   'probabl',
#   'tabl',
#   'forecast',
#   'risk',
#   'liabil',
#   'payment',
#   'futur',
#   'benefit',
#   'ascertain',
#   'insur',
#   'rate',
#   'requir',
#   'cash',
#   'reserv',
#   'necessari',
#   'ensur',
#   'payment',
#   'futur',
#   'benefit'],
#  ['research',
#   'fundament',
#   'mathemat',
#   'applic',
#   'mathemat',
#   'techniqu',
#   'scienc',
#   'manag',
#   'field',
#   'problem',
#   'various',
#   'field',
#   'use',
#   'mathemat',
#   'method'],
#  ['appli',
#   'mathemat',
#   'model',
#   'optim',
#   'method',
#   'develop',
#   'interpret',
#   'inform',
#   'assist',
#   'manag',
#   'decis',
#   'make',
#   'polici',
#   'formul',
#   'manageri',
#   'function',
#   'collect',
#   'analyz',
#   'data',
#   'develop',
#   'decis',
#   'support',
#   'softwar',
#   'servic',
#   'product',
#   'develop',
#   'suppli',
#   'optim',
#   'time',
#   'cost',
#   'logist',
#   'network',
#   'program',
#   'evalu',
#   'review',
#   'implement'],
#  ['appli',
#   'mathemat',
#   'statist',
#   'theori',
#   'method',
#   'collect',
#   'organ',
#   'interpret',
#   'summar',
#   'numer',
#   'data',
#   'provid',
#   'usabl',
#   'inform',
#   'special',
#   'field',
#   'bio-statist',
#   'agricultur',
#   'statist',
#   'busi',
#   'statist',
#   'econom',
#   'statist',
#   'mathemat',
#   'survey',
#   'statistician'],
#  ['appli', 'biostatist', 'theori', 'method', 'studi', 'life', 'scienc'],
#  ['knowledg',
#   'health',
#   'care',
#   'databas',
#   'manag',
#   'analyz',
#   'clinic',
#   'data',
#   'identifi',
#   'report',
#   'trend'],
#  ['standard',
#   'mathemat',
#   'formula',
#   'principl',
#   'methodolog',
#   'technolog',
#   'problem',
#   'engin',
#   'physic',
#   'scienc',
#   'relat',
#   'specif',
#   'industri',
#   'research',
#   'object',
#   'process',
#   'equip',
#   'product'],
#  ['mathemat', 'scientist', 'list', 'separ'],
#  ['design',
#   'structur',
#   'privat',
#   'resid',
#   'offic',
#   'build',
#   'theater',
#   'factori',
#   'structur',
#   'properti'],
#  ['design',
#   'land',
#   'area',
#   'project',
#   'park',
#   'recreat',
#   'facil',
#   'airport',
#   'highway',
#   'hospit',
#   'school',
#   'land',
#   'subdivis',
#   'commerci',
#   'industri',
#   'residenti',
#   'site'],
#  ['analyz',
#   'interpret',
#   'geograph',
#   'inform',
#   'provid',
#   'geodet',
#   'survey',
#   'aerial',
#   'photograph',
#   'satellit',
#   'data',
#   'studi',
#   'prepar',
#   'map',
#   'spatial',
#   'data',
#   'digit',
#   'graphic',
#   'form',
#   'legal',
#   'social',
#   'polit',
#   'educ',
#   'design',
#   'purpos',
#   'work',
#   'design',
#   'evalu',
#   'algorithm',
#   'data',
#   'structur',
#   'user',
#   'interfac',
#   'map',
#   'system'],
#  ['exact',
#   'measur',
#   'determin',
#   'properti',
#   'boundari',
#   'data',
#   'relev',
#   'shape',
#   'contour',
#   'gravit',
#   'locat',
#   'elev',
#   'dimens',
#   'land',
#   'land',
#   'featur',
#   'near',
#   'earth',
#   "'s",
#   'surfac',
#   'engin',
#   'mapmak',
#   'mine',
#   'land',
#   'evalu',
#   'construct',
#   'purpos'],
#  ['larg',
#   'area',
#   "'s",
#   'surfac',
#   'use',
#   'satellit',
#   'observ',
#   'global',
#   'navig',
#   'satellit',
#   'system',
#   'light',
#   'detect',
#   'rang',
#   'relat',
#   'sourc'],
#  ['engin',
#   'duti',
#   'design',
#   'construct',
#   'test',
#   'aircraft',
#   'missil',
#   'spacecraft',
#   'conduct',
#   'basic',
#   'appli',
#   'research',
#   'evalu',
#   'adapt',
#   'materi',
#   'equip',
#   'aircraft',
#   'design',
#   'manufactur',
#   'recommend',
#   'improv',
#   'test',
#   'equip',
#   'techniqu'],
#  ['knowledg',
#   'engin',
#   'technolog',
#   'biolog',
#   'scienc',
#   'agricultur',
#   'problem',
#   'concern',
#   'power',
#   'machineri',
#   'electrif',
#   'structur',
#   'soil',
#   'water',
#   'conserv',
#   'process',
#   'agricultur',
#   'product'],
#  ['knowledg',
#   'engin',
#   'biolog',
#   'biomechan',
#   'principl',
#   'design',
#   'develop',
#   'evalu',
#   'biolog',
#   'health',
#   'system',
#   'product',
#   'artifici',
#   'organ',
#   'prosthes',
#   'instrument',
#   'medic',
#   'inform',
#   'system',
#   'health',
#   'manag',
#   'care',
#   'deliveri',
#   'system'],
#  ['chemic',
#   'plant',
#   'equip',
#   'devis',
#   'process',
#   'manufactur',
#   'chemic',
#   'product',
#   'gasolin',
#   'synthet',
#   'rubber',
#   'plastic',
#   'deterg',
#   'cement',
#   'paper',
#   'pulp',
#   'appli',
#   'principl',
#   'technolog',
#   'chemistri',
#   'physic',
#   'engin'],
#  ['engin',
#   'duti',
#   'plan',
#   'design',
#   'overse',
#   'construct',
#   'mainten',
#   'build',
#   'structur',
#   'facil',
#   'road',
#   'railroad',
#   'airport',
#   'bridg',
#   'harbor',
#   'channel',
#   'dam',
#   'irrig',
#   'project',
#   'pipelin',
#   'power',
#   'plant',
#   'water',
#   'sewag',
#   'system'],
#  ['plan',
#   'surfac',
#   'transport',
#   'project',
#   'accord',
#   'establish',
#   'engin',
#   'standard',
#   'state',
#   'feder',
#   'construct',
#   'polici',
#   'design',
#   'specif',
#   'estim',
#   'transport',
#   'facil',
#   'modif',
#   'exist',
#   'street',
#   'highway',
#   'freeway',
#   'improv',
#   'traffic',
#   'flow'],
#  ['design',
#   'develop',
#   'test',
#   'comput',
#   'computer-rel',
#   'equip',
#   'commerci',
#   'industri',
#   'militari',
#   'scientif',
#   'use',
#   'supervis',
#   'manufactur',
#   'instal',
#   'comput',
#   'computer-rel',
#   'equip',
#   'compon'],
#  ['design',
#   'develop',
#   'test',
#   'supervis',
#   'manufactur',
#   'instal',
#   'electr',
#   'equip',
#   'compon',
#   'system',
#   'commerci',
#   'industri',
#   'militari',
#   'scientif',
#   'use'],
#  ['design',
#   'develop',
#   'test',
#   'electron',
#   'compon',
#   'system',
#   'commerci',
#   'industri',
#   'militari',
#   'scientif',
#   'use',
#   'employ',
#   'knowledg',
#   'electron',
#   'theori',
#   'materi',
#   'properti',
#   'electron',
#   'circuit',
#   'compon',
#   'use',
#   'field',
#   'telecommun',
#   'aerospac',
#   'guidanc',
#   'propuls',
#   'control',
#   'acoust',
#   'instrument',
#   'control'],
#  ['implement',
#   'radio',
#   'frequenc',
#   'identif',
#   'devic',
#   'system',
#   'use',
#   'track',
#   'shipment',
#   'good'],
#  ['design',
#   'plan',
#   'perform',
#   'engin',
#   'duti',
#   'prevent',
#   'control',
#   'remedi',
#   'environment',
#   'hazard',
#   'use',
#   'various',
#   'engin',
#   'disciplin',
#   'may',
#   'includ',
#   'wast',
#   'treatment',
#   'site',
#   'remedi',
#   'pollut',
#   'control',
#   'technolog'],
#  ['overse',
#   'project',
#   'involv',
#   'provis',
#   'potabl',
#   'water',
#   'dispos',
#   'wastewat',
#   'sewag',
#   'prevent',
#   'flood-rel',
#   'damag',
#   'environment',
#   'document',
#   'water',
#   'resourc',
#   'regulatori',
#   'program',
#   'complianc',
#   'data',
#   'manag',
#   'analysi',
#   'field',
#   'work',
#   'hydraul',
#   'model',
#   'pipelin',
#   'design'],
#  ['worksit',
#   'product',
#   'safeti',
#   'appli',
#   'knowledg',
#   'industri',
#   'process',
#   'mechan',
#   'chemistri',
#   'psycholog',
#   'industri',
#   'health',
#   'safeti',
#   'law',
#   'industri',
#   'product',
#   'safeti',
#   'engin'],
#  ['implement',
#   'coordin',
#   'safeti',
#   'program',
#   'requir',
#   'applic',
#   'engin',
#   'principl',
#   'technolog',
#   'prevent',
#   'correct',
#   'unsaf',
#   'environment',
#   'work',
#   'condit'],
#  ['caus',
#   'fire',
#   'determin',
#   'fire',
#   'protect',
#   'method',
#   'design',
#   'recommend',
#   'materi',
#   'equip',
#   'structur',
#   'compon',
#   'fire-detect',
#   'equip',
#   'assist',
#   'organ',
#   'safeguard',
#   'life',
#   'properti',
#   'fire',
#   'explos',
#   'relat',
#   'hazard'],
#  ['conduct',
#   'test',
#   'evalu',
#   'product',
#   'safeti',
#   'level',
#   'recommend',
#   'measur',
#   'reduc',
#   'elimin',
#   'hazard'],
#  ['develop',
#   'test',
#   'evalu',
#   'integr',
#   'system',
#   'manag',
#   'industri',
#   'product',
#   'process',
#   'includ',
#   'human',
#   'work',
#   'factor',
#   'qualiti',
#   'control',
#   'inventori',
#   'control',
#   'logist',
#   'materi',
#   'flow',
#   'cost',
#   'analysi',
#   'product',
#   'coordin'],
#  ['object',
#   'facil',
#   'environ',
#   'optim',
#   'human',
#   'well-b',
#   'overal',
#   'system',
#   'perform',
#   'appli',
#   'theori',
#   'principl',
#   'data',
#   'regard',
#   'relationship',
#   'human',
#   'respect',
#   'technolog',
#   'analyz',
#   'characterist',
#   'human',
#   'behavior',
#   'perform',
#   'relat',
#   'use',
#   'technolog'],
#  ['develop',
#   'evalu',
#   'oper',
#   'marin',
#   'vessel',
#   'ship',
#   'machineri',
#   'relat',
#   'equip',
#   'power',
#   'suppli',
#   'propuls',
#   'system'],
#  ['develop',
#   'take',
#   'respons',
#   'instal',
#   'ship',
#   'machineri',
#   'relat',
#   'equip',
#   'includ',
#   'propuls',
#   'machin',
#   'power',
#   'suppli',
#   'system'],
#  ['overse',
#   'construct',
#   'repair',
#   'marin',
#   'craft',
#   'float',
#   'structur',
#   'ship',
#   'barg',
#   'tug',
#   'dredg',
#   'submarin',
#   'torpedo',
#   'float',
#   'buoy',
#   'confer',
#   'marin',
#   'engin'],
#  ['materi',
#   'develop',
#   'machineri',
#   'process',
#   'manufactur',
#   'materi',
#   'use',
#   'product',
#   'must',
#   'meet',
#   'special',
#   'design',
#   'perform',
#   'specif',
#   'new',
#   'use',
#   'known',
#   'materi',
#   'engin',
#   'work',
#   'composit',
#   'materi',
#   'special',
#   'one',
#   'type',
#   'materi',
#   'graphit',
#   'metal',
#   'metal',
#   'alloy',
#   'ceram',
#   'glass',
#   'plastic',
#   'polym',
#   'natur',
#   'occur',
#   'materi',
#   'metallurgist',
#   'metallurg',
#   'engin',
#   'ceram',
#   'engin',
#   'weld',
#   'engin'],
#  ['engin',
#   'duti',
#   'plan',
#   'design',
#   'tool',
#   'engin',
#   'machin',
#   'mechan',
#   'function',
#   'equip',
#   'instal',
#   'oper',
#   'mainten',
#   'repair',
#   'equip',
#   'central',
#   'heat',
#   'gas',
#   'water',
#   'steam',
#   'system'],
#  ['evalu',
#   'modifi',
#   'construct',
#   'fuel',
#   'cell',
#   'compon',
#   'system',
#   'transport',
#   'stationari',
#   'portabl',
#   'applic'],
#  ['new',
#   'improv',
#   'design',
#   'vehicl',
#   'structur',
#   'member',
#   'engin',
#   'transmiss',
#   'vehicl',
#   'system',
#   'use',
#   'computer-assist',
#   'design',
#   'technolog',
#   'build',
#   'modif',
#   'test',
#   'vehicl',
#   'compon'],
#  ['sub-surfac',
#   'survey',
#   'identifi',
#   'characterist',
#   'potenti',
#   'land',
#   'mine',
#   'develop',
#   'site',
#   'specifi',
#   'ground',
#   'support',
#   'system',
#   'process',
#   'equip',
#   'safe',
#   'econom',
#   'environment',
#   'sound',
#   'extract',
#   'underground',
#   'construct',
#   'activ',
#   'inspect',
#   'area',
#   'unsaf',
#   'geolog',
#   'condit',
#   'equip',
#   'work',
#   'condit',
#   'design',
#   'implement',
#   'coordin',
#   'mine',
#   'safeti',
#   'program'],
#  ['research',
#   'nuclear',
#   'engin',
#   'project',
#   'appli',
#   'principl',
#   'theori',
#   'nuclear',
#   'scienc',
#   'problem',
#   'concern',
#   'releas',
#   'control',
#   'use',
#   'nuclear',
#   'energi',
#   'nuclear',
#   'wast',
#   'dispos'],
#  ['method',
#   'improv',
#   'oil',
#   'gas',
#   'extract',
#   'product',
#   'determin',
#   'need',
#   'new',
#   'modifi',
#   'tool',
#   'design',
#   'drill',
#   'offer',
#   'technic',
#   'advic'],
#  ['engin', 'list', 'separ'],
#  ['usabl',
#   'tangibl',
#   'product',
#   'use',
#   'knowledg',
#   'biolog',
#   'chemistri',
#   'engin',
#   'problem',
#   'relat',
#   'materi',
#   'system',
#   'process',
#   'interact',
#   'human',
#   'plant',
#   'anim',
#   'microorgan',
#   'biolog',
#   'materi'],
#  ['plan',
#   'protocol',
#   'equip',
#   'process',
#   'produc',
#   'product',
#   'meet',
#   'intern',
#   'extern',
#   'puriti',
#   'safeti',
#   'qualiti',
#   'requir'],
#  ['develop',
#   'evalu',
#   'energy-rel',
#   'project',
#   'program',
#   'reduc',
#   'energi',
#   'cost',
#   'improv',
#   'energi',
#   'effici',
#   'dure',
#   'design',
#   'build',
#   'remodel',
#   'stage',
#   'construct',
#   'special',
#   'electr',
#   'system',
#   'heat',
#   'ventil',
#   'air-condit',
#   'system',
#   'green',
#   'build',
#   'light',
#   'air',
#   'qualiti',
#   'energi',
#   'procur'],
#  ['integr',
#   'improv',
#   'manufactur',
#   'system',
#   'relat',
#   'process',
#   'work',
#   'commerci',
#   'industri',
#   'design',
#   'refin',
#   'product',
#   'design',
#   'increas',
#   'produc',
#   'decreas',
#   'cost'],
#  ['design',
#   'develop',
#   'test',
#   'autom',
#   'intellig',
#   'system',
#   'smart',
#   'devic',
#   'industri',
#   'system',
#   'control'],
#  ['design', 'develop', 'test', 'microelectromechan', 'system', 'devic'],
#  ['technolog',
#   'special',
#   'light',
#   'inform',
#   'light',
#   'energi',
#   'laser',
#   'fiber',
#   'optic',
#   'technolog'],
#  ['design', 'develop', 'test', 'robot', 'applic'],
#  ['develop',
#   'supervis',
#   'product',
#   'materi',
#   'devic',
#   'system',
#   'uniqu',
#   'molecular',
#   'macromolecular',
#   'composit',
#   'appli',
#   'principl',
#   'nanoscal',
#   'physic',
#   'electr',
#   'chemic',
#   'biolog',
#   'engin'],
#  ['underground',
#   'overhead',
#   'wind',
#   'farm',
#   'collector',
#   'system',
#   'prepar',
#   'develop',
#   'site',
#   'specif'],
#  ['site-specif',
#   'engin',
#   'analysi',
#   'evalu',
#   'energi',
#   'effici',
#   'solar',
#   'project',
#   'involv',
#   'residenti',
#   'commerci',
#   'industri',
#   'custom',
#   'solar',
#   'domest',
#   'hot',
#   'water',
#   'space',
#   'heat',
#   'system',
#   'new',
#   'exist',
#   'structur',
#   'appli',
#   'knowledg',
#   'structur',
#   'energi',
#   'requir',
#   'local',
#   'climat',
#   'solar',
#   'technolog',
#   'thermodynam'],
#  ['detail',
#   'draw',
#   'architectur',
#   'structur',
#   'featur',
#   'build',
#   'draw',
#   'topograph',
#   'relief',
#   'map',
#   'use',
#   'civil',
#   'engin',
#   'project',
#   'highway',
#   'bridg',
#   'public',
#   'work',
#   'knowledg',
#   'build',
#   'materi',
#   'engin',
#   'practic',
#   'mathemat',
#   'complet',
#   'draw'],
#  ['detail',
#   'draw',
#   'architectur',
#   'design',
#   'plan',
#   'build',
#   'structur',
#   'accord',
#   'specif',
#   'provid',
#   'architect'],
#  ['draw',
#   'topograph',
#   'relief',
#   'map',
#   'use',
#   'civil',
#   'engin',
#   'project',
#   'highway',
#   'bridg',
#   'pipelin',
#   'flood',
#   'control',
#   'project',
#   'water',
#   'sewerag',
#   'control',
#   'system'],
#  ['wire',
#   'diagram',
#   'circuit',
#   'board',
#   'assembl',
#   'diagram',
#   'layout',
#   'draw',
#   'use',
#   'manufactur',
#   'instal',
#   'repair',
#   'electr',
#   'equip'],
#  ['wire',
#   'diagram',
#   'circuit',
#   'board',
#   'assembl',
#   'diagram',
#   'schemat',
#   'layout',
#   'draw',
#   'use',
#   'manufactur',
#   'instal',
#   'repair',
#   'electron',
#   'equip'],
#  ['specif',
#   'instruct',
#   'instal',
#   'voltag',
#   'transform',
#   'overhead',
#   'underground',
#   'cabl',
#   'relat',
#   'electr',
#   'equip',
#   'use',
#   'conduct',
#   'electr',
#   'energi',
#   'transmiss',
#   'line',
#   'high-voltag',
#   'distribut',
#   'line',
#   'consum'],
#  ['detail',
#   'work',
#   'diagram',
#   'machineri',
#   'mechan',
#   'devic',
#   'includ',
#   'dimens',
#   'fasten',
#   'method',
#   'engin',
#   'inform'],
#  ['drafter', 'list', 'separ'],
#  ['instal',
#   'calibr',
#   'maintain',
#   'integr',
#   'computer/commun',
#   'system',
#   'consol',
#   'simul',
#   'data',
#   'acquisit',
#   'test',
#   'measur',
#   'instrument',
#   'equip',
#   'use',
#   'launch',
#   'track',
#   'posit',
#   'evalu',
#   'air',
#   'space',
#   'vehicl',
#   'record',
#   'interpret',
#   'test',
#   'data'],
#  ['theori',
#   'principl',
#   'civil',
#   'engin',
#   'plan',
#   'design',
#   'overse',
#   'construct',
#   'mainten',
#   'structur',
#   'facil',
#   'direct',
#   'engin',
#   'staff',
#   'physic',
#   'scientist'],
#  ['electr',
#   'electron',
#   'theori',
#   'relat',
#   'knowledg',
#   'usual',
#   'direct',
#   'engin',
#   'staff',
#   'design',
#   'build',
#   'repair',
#   'calibr',
#   'modifi',
#   'electr',
#   'compon',
#   'circuitri',
#   'control',
#   'machineri',
#   'subsequ',
#   'evalu',
#   'use',
#   'engin',
#   'staff',
#   'make',
#   'engin',
#   'design',
#   'decis'],
#  ['build',
#   'test',
#   'troubleshoot',
#   'repair',
#   'modifi',
#   'development',
#   'product',
#   'electron',
#   'compon',
#   'part',
#   'equip',
#   'system',
#   'comput',
#   'equip',
#   'missil',
#   'control',
#   'instrument',
#   'electron',
#   'tube',
#   'test',
#   'equip',
#   'machin',
#   'tool',
#   'numer',
#   'control',
#   'appli',
#   'principl',
#   'theori',
#   'electron',
#   'electr',
#   'circuitri',
#   'engin',
#   'mathemat',
#   'electron',
#   'electr',
#   'test',
#   'physic',
#   'work',
#   'direct',
#   'engin',
#   'staff'],
#  ['modifi',
#   'development',
#   'oper',
#   'electr',
#   'machineri',
#   'electr',
#   'control',
#   'equip',
#   'circuitri',
#   'industri',
#   'commerci',
#   'plant',
#   'laboratori',
#   'work',
#   'direct',
#   'engin',
#   'technologist'],
#  ['test',
#   'maintain',
#   'calibr',
#   'unman',
#   'autom',
#   'servo-mechan',
#   'electromechan',
#   'equip',
#   'oper',
#   'unman',
#   'submarin',
#   'aircraft',
#   'equip',
#   'worksit',
#   'oil',
#   'rig',
#   'deep',
#   'ocean',
#   'explor',
#   'hazard',
#   'wast',
# ...
#   'key',
#   'chang',
#   'lock',
#   'safe',
#   'combin',
#   'instal',
#   'repair',
#   'safe'],
#  ['instal', 'mobil', 'home', 'prefabr', 'build'],
#  ['repair',
#   'rig',
#   'construct',
#   'project',
#   'manufactur',
#   'plant',
#   'log',
#   'yard',
#   'ship',
#   'shipyard',
#   'entertain',
#   'industri'],
#  ['inspect',
#   'test',
#   'maintain',
#   'repair',
#   'electr',
#   'gate',
#   'cross',
#   'signal',
#   'signal',
#   'equip',
#   'track',
#   'switch',
#   'section',
#   'line',
#   'intercommun',
#   'system',
#   'within',
#   'railroad',
#   'system'],
#  ['instal',
#   'mainten',
#   'repair',
#   'worker',
#   'mainten',
#   'part',
#   'replac',
#   'repair',
#   'vehicl',
#   'industri',
#   'machineri',
#   'electr',
#   'electron',
#   'equip',
#   'duti',
#   'furnish',
#   'tool',
#   'materi',
#   'suppli',
#   'worker',
#   'clean',
#   'work',
#   'area',
#   'machin',
#   'tool',
#   'hold',
#   'materi',
#   'tool',
#   'worker'],
#  ['instal', 'mainten', 'repair', 'worker', 'list', 'separ'],
#  ['technic',
#   'activ',
#   'power',
#   'plant',
#   'individu',
#   'instal',
#   'necessari',
#   'generat',
#   'power',
#   'geotherm',
#   'energi',
#   'sourc',
#   'control',
#   'oper',
#   'activ',
#   'geotherm',
#   'power',
#   'generat',
#   'facil',
#   'perform',
#   'mainten',
#   'repair',
#   'necessari',
#   'test',
#   'maintain',
#   'residenti',
#   'commerci',
#   'geotherm',
#   'heat',
#   'pump'],
#  ['supervis',
#   'coordin',
#   'activ',
#   'product',
#   'oper',
#   'worker',
#   'inspector',
#   'precis',
#   'worker',
#   'machin',
#   'setter',
#   'oper',
#   'assembl',
#   'fabric',
#   'plant',
#   'system',
#   'oper'],
#  ['fit',
#   'fasten',
#   'instal',
#   'part',
#   'airplan',
#   'space',
#   'vehicl',
#   'missil',
#   'tail',
#   'wing',
#   'fuselag',
#   'bulkhead',
#   'stabil',
#   'land',
#   'gear',
#   'rig',
#   'control',
#   'equip',
#   'heat',
#   'ventil',
#   'system'],
#  ['wire',
#   'coil',
#   'use',
#   'electr',
#   'compon',
#   'resistor',
#   'transform',
#   'electr',
#   'equip',
#   'instrument',
#   'field',
#   'core',
#   'bobbin',
#   'armatur',
#   'core',
#   'electr',
#   'motor',
#   'generat',
#   'control',
#   'equip'],
#  ['modifi',
#   'electr',
#   'electron',
#   'equip',
#   'comput',
#   'test',
#   'equip',
#   'telemet',
#   'system',
#   'electr',
#   'motor',
#   'batteri'],
#  ['modifi',
#   'electromechan',
#   'equip',
#   'devic',
#   'servomechan',
#   'gyro',
#   'dynamomet',
#   'magnet',
#   'drum',
#   'tape',
#   'drive',
#   'brake',
#   'control',
#   'linkag',
#   'actuat',
#   'applianc'],
#  ['assembl',
#   'rebuild',
#   'machin',
#   'engin',
#   'turbin',
#   'similar',
#   'equip',
#   'use',
#   'industri',
#   'construct',
#   'extract',
#   'textil',
#   'paper',
#   'manufactur'],
#  ['posit', 'align', 'fit', 'part', 'structur', 'metal', 'product'],
#  ['layer',
#   'fiberglass',
#   'mold',
#   'form',
#   'boat',
#   'deck',
#   'hull',
#   'bodi',
#   'golf',
#   'cart',
#   'automobil',
#   'product'],
#  ['part',
#   'team',
#   'respons',
#   'assembl',
#   'entir',
#   'product',
#   'compon',
#   'product',
#   'assembl',
#   'perform',
#   'task',
#   'conduct',
#   'team',
#   'assembl',
#   'process',
#   'rotat',
#   'rather',
#   'assign',
#   'specif',
#   'task',
#   'perman',
#   'basi',
#   'particip',
#   'make',
#   'manag',
#   'decis',
#   'affect',
#   'work',
#   'team',
#   'leader',
#   'work',
#   'part',
#   'team'],
#  ['precis',
#   'assembl',
#   'adjust',
#   'calibr',
#   'within',
#   'narrow',
#   'toler',
#   'time',
#   'devic',
#   'digit',
#   'clock',
#   'time',
#   'devic',
#   'electr',
#   'electron',
#   'compon'],
#  ['assembl', 'fabric', 'list', 'separ'],
#  ['bake',
#   'ingredi',
#   'produc',
#   'bread',
#   'roll',
#   'cooki',
#   'cake',
#   'pie',
#   'pastri',
#   'bake',
#   'good'],
#  ['trim',
#   'prepar',
#   'consumer-s',
#   'portion',
#   'meat',
#   'use',
#   'sale',
#   'retail',
#   'establish'],
#  ['hand',
#   'hand',
#   'tool',
#   'perform',
#   'routin',
#   'cut',
#   'trim',
#   'meat',
#   'poultri',
#   'seafood'],
#  ['slaughter',
#   'meat',
#   'pack',
#   'wholesal',
#   'establish',
#   'perform',
#   'precis',
#   'function',
#   'involv',
#   'prepar',
#   'meat',
#   'may',
#   'includ',
#   'special',
#   'slaughter',
#   'task',
#   'cut',
#   'standard',
#   'premium',
#   'cut',
#   'meat',
#   'market',
#   'make',
#   'sausag',
#   'wrap',
#   'meat'],
#  ['tend',
#   'food',
#   'tobacco',
#   'roast',
#   'bake',
#   'dri',
#   'equip',
#   'includ',
#   'hearth',
#   'oven',
#   'kiln',
#   'drier',
#   'roaster',
#   'char',
#   'kiln',
#   'vacuum',
#   'dri',
#   'equip'],
#  ['oper',
#   'equip',
#   'mix',
#   'blend',
#   'ingredi',
#   'use',
#   'manufactur',
#   'food',
#   'product',
#   'candi',
#   'maker',
#   'chees',
#   'maker'],
#  ['tend',
#   'cook',
#   'equip',
#   'steam',
#   'cook',
#   'vat',
#   'deep',
#   'fri',
#   'cooker',
#   'pressur',
#   'cooker',
#   'kettl',
#   'boiler',
#   'prepar',
#   'food',
#   'product'],
#  ['food', 'process', 'worker', 'list', 'separ'],
#  ['computer-control',
#   'machin',
#   'robot',
#   'perform',
#   'one',
#   'machin',
#   'function',
#   'metal',
#   'plastic',
#   'work',
#   'piec'],
#  ['program',
#   'control',
#   'machin',
#   'process',
#   'metal',
#   'plastic',
#   'part',
#   'automat',
#   'machin',
#   'tool',
#   'equip',
#   'system'],
#  ['oper',
#   'tend',
#   'machin',
#   'extrud',
#   'draw',
#   'thermoplast',
#   'metal',
#   'materi',
#   'tube',
#   'rod',
#   'hose',
#   'wire',
#   'bar',
#   'structur',
#   'shape'],
#  ['oper',
#   'tend',
#   'forg',
#   'machin',
#   'taper',
#   'shape',
#   'form',
#   'metal',
#   'plastic',
#   'part'],
#  ['oper',
#   'tend',
#   'machin',
#   'roll',
#   'steel',
#   'plastic',
#   'form',
#   'bend',
#   'bead',
#   'knurl',
#   'roll',
#   'plate',
#   'flatten',
#   'temper',
#   'reduc',
#   'gaug',
#   'materi'],
#  ['oper',
#   'tend',
#   'machin',
#   'saw',
#   'cut',
#   'shear',
#   'slit',
#   'punch',
#   'crimp',
#   'notch',
#   'bend',
#   'straighten',
#   'metal',
#   'plastic',
#   'materi'],
#  ['oper',
#   'tend',
#   'drill',
#   'machin',
#   'drill',
#   'bore',
#   'ream',
#   'mill',
#   'countersink',
#   'metal',
#   'plastic',
#   'work',
#   'piec'],
#  ['oper',
#   'tend',
#   'grind',
#   'relat',
#   'tool',
#   'remov',
#   'excess',
#   'materi',
#   'burr',
#   'surfac',
#   'sharpen',
#   'edg',
#   'corner',
#   'buff',
#   'hone',
#   'polish',
#   'metal',
#   'plastic',
#   'work',
#   'piec'],
#  ['oper',
#   'tend',
#   'lath',
#   'turn',
#   'machin',
#   'turn',
#   'bore',
#   'thread',
#   'form',
#   'face',
#   'metal',
#   'plastic',
#   'materi',
#   'wire',
#   'rod',
#   'bar',
#   'stock'],
#  ['oper',
#   'tend',
#   'mill',
#   'plane',
#   'machin',
#   'mill',
#   'plane',
#   'shape',
#   'groov',
#   'profil',
#   'metal',
#   'plastic',
#   'work',
#   'piec'],
#  ['oper',
#   'varieti',
#   'machin',
#   'tool',
#   'produc',
#   'precis',
#   'part',
#   'instrument',
#   'precis',
#   'instrument',
#   'maker',
#   'fabric',
#   'modifi',
#   'repair',
#   'mechan',
#   'instrument',
#   'also',
#   'fabric',
#   'modifi',
#   'part',
#   'make',
#   'repair',
#   'machin',
#   'tool',
#   'maintain',
#   'industri',
#   'machin',
#   'appli',
#   'knowledg',
#   'mechan',
#   'mathemat',
#   'metal',
#   'properti',
#   'layout',
#   'machin',
#   'procedur'],
#  ['tend',
#   'furnac',
#   'gas',
#   'oil',
#   'coal',
#   'electric-arc',
#   'electr',
#   'induct',
#   'open-hearth',
#   'oxygen',
#   'furnac',
#   'melt',
#   'refin',
#   'metal',
#   'befor',
#   'cast',
#   'produc',
#   'specifi',
#   'type',
#   'steel'],
#  ['hand-control',
#   'mechan',
#   'pour',
#   'regul',
#   'flow',
#   'molten',
#   'metal',
#   'mold',
#   'produc',
#   'cast',
#   'ingot'],
#  ['oper',
#   'machin',
#   'lath',
#   'mill',
#   'engrav',
#   'machin',
#   'jig',
#   'borer',
#   'make',
#   'work',
#   'model',
#   'metal',
#   'plastic',
#   'object',
#   'templat',
#   'maker'],
#  ['machin',
#   'fit',
#   'assembl',
#   'cast',
#   'part',
#   'metal',
#   'plastic',
#   'foundri',
#   'pattern',
#   'core',
#   'box',
#   'match',
#   'plate'],
#  ['form',
#   'wax',
#   'sand',
#   'core',
#   'mold',
#   'use',
#   'product',
#   'metal',
#   'cast',
#   'foundri'],
#  ['oper',
#   'tend',
#   'metal',
#   'plastic',
#   'mold',
#   'cast',
#   'coremak',
#   'machin',
#   'mold',
#   'cast',
#   'metal',
#   'thermoplast',
#   'part',
#   'product'],
#  ['oper', 'tend', 'one', 'type', 'cut', 'form', 'machin', 'tool', 'robot'],
#  ['specif',
#   'lay',
#   'metal',
#   'stock',
#   'set',
#   'oper',
#   'machin',
#   'tool',
#   'fit',
#   'assembl',
#   'part',
#   'make',
#   'repair',
#   'die',
#   'cut',
#   'tool',
#   'jig',
#   'fixtur',
#   'gaug',
#   'machinist',
#   'hand',
#   'tool'],
#  ['hand-weld',
#   'flame-cut',
#   'hand',
#   'solder',
#   'braze',
#   'equip',
#   'weld',
#   'join',
#   'metal',
#   'compon',
#   'fill',
#   'hole',
#   'indent',
#   'seam',
#   'fabric',
#   'metal',
#   'product'],
#  ['hand-weld',
#   'flame-cut',
#   'equip',
#   'weld',
#   'join',
#   'metal',
#   'compon',
#   'fill',
#   'hole',
#   'indent',
#   'seam',
#   'fabric',
#   'metal',
#   'product'],
#  ['solder',
#   'togeth',
#   'compon',
#   'assembl',
#   'fabric',
#   'metal',
#   'part',
#   'use',
#   'solder',
#   'iron',
#   'torch',
#   'weld',
#   'machin',
#   'flux'],
#  ['oper',
#   'tend',
#   'weld',
#   'solder',
#   'braze',
#   'machin',
#   'robot',
#   'weld',
#   'braze',
#   'solder',
#   'heat',
#   'treat',
#   'metal',
#   'product',
#   'compon',
#   'assembl',
#   'worker',
#   'oper',
#   'laser',
#   'cutter',
#   'laser-beam',
#   'machin'],
#  ['oper',
#   'tend',
#   'heat',
#   'equip',
#   'heat-treat',
#   'furnac',
#   'flame-harden',
#   'machin',
#   'induct',
#   'machin',
#   'soak',
#   'pit',
#   'vacuum',
#   'equip',
#   'temper',
#   'harden',
#   'anneal',
#   'heat-treat',
#   'metal',
#   'plastic',
#   'object'],
#  ['refer',
#   'point',
#   'dimens',
#   'metal',
#   'plastic',
#   'stock',
#   'workpiec',
#   'sheet',
#   'plate',
#   'tube',
#   'structur',
#   'shape',
#   'cast',
#   'machin',
#   'part',
#   'process',
#   'shipfitt'],
#  ['oper',
#   'tend',
#   'plate',
#   'coat',
#   'machin',
#   'coat',
#   'metal',
#   'plastic',
#   'product',
#   'chromium',
#   'zinc',
#   'copper',
#   'cadmium',
#   'nickel',
#   'metal',
#   'protect',
#   'decor',
#   'surfac',
#   'electrolyt',
#   'process'],
#  ['precis', 'smooth', 'sharpen', 'polish', 'grind', 'metal', 'object'],
#  ['metal', 'worker', 'plastic', 'worker', 'list', 'separ'],
#  ['proof',
#   'text',
#   'imag',
#   'submit',
#   'design',
#   'client',
#   'finish',
#   'page',
#   'print',
#   'digit',
#   'photo',
#   'typeset',
#   'produc',
#   'print',
#   'plate'],
#  ['oper',
#   'digit',
#   'letterpress',
#   'lithograph',
#   'flexograph',
#   'gravur',
#   'print',
#   'machin',
#   'short-run',
#   'offset',
#   'print',
#   'press'],
#  ['book',
#   'public',
#   'finish',
#   'print',
#   'product',
#   'hand',
#   'machin',
#   'set',
#   'bind',
#   'finish',
#   'machin'],
#  ['tend',
#   'wash',
#   'dry-clean',
#   'machin',
#   'wash',
#   'dry-clean',
#   'industri',
#   'household',
#   'articl',
#   'cloth',
#   'garment',
#   'sued',
#   'leather',
#   'fur',
#   'blanket',
#   'draperi',
#   'linen',
#   'rug',
#   'carpet',
#   'spotter',
#   'dyer',
#   'articl'],
#  ['shape', 'articl', 'hand', 'machin'],
#  ['tend',
#   'sew',
#   'machin',
#   'join',
#   'reinforc',
#   'decor',
#   'perform',
#   'relat',
#   'sew',
#   'oper',
#   'manufactur',
#   'garment',
#   'nongar',
#   'product'],
#  ['decor',
#   'repair',
#   'leather',
#   'leather-lik',
#   'product',
#   'luggag',
#   'shoe',
#   'saddl'],
#  ['tend',
#   'varieti',
#   'machin',
#   'join',
#   'decor',
#   'reinforc',
#   'finish',
#   'shoe',
#   'shoe',
#   'part'],
#  ['join',
#   'reinforc',
#   'finish',
#   'usual',
#   'needl',
#   'thread',
#   'varieti',
#   'manufactur',
#   'item',
#   'weaver',
#   'stitcher'],
#  ['make', 'alter', 'repair', 'fit', 'garment'],
#  ['tend',
#   'machin',
#   'bleach',
#   'shrink',
#   'wash',
#   'dye',
#   'finish',
#   'textil',
#   'synthet',
#   'glass',
#   'fiber'],
#  ['oper', 'tend', 'machin', 'cut', 'textil'],
#  ['oper', 'tend', 'machin', 'knit', 'loop', 'weav', 'draw', 'textil'],
#  ['oper',
#   'tend',
#   'machin',
#   'wind',
#   'twist',
#   'textil',
#   'draw',
#   'combin',
#   'sliver',
#   'wool',
#   'hemp',
#   'synthet',
#   'fiber',
#   'slubber',
#   'machin',
#   'draw',
#   'frame',
#   'oper'],
#  ['oper',
#   'tend',
#   'machin',
#   'extrud',
#   'form',
#   'continu',
#   'filament',
#   'synthet',
#   'materi',
#   'liquid',
#   'polym',
#   'rayon',
#   'fiberglass'],
#  ['construct',
#   'set',
#   'precis',
#   'master',
#   'fabric',
#   'pattern',
#   'layout',
#   'also',
#   'mark',
#   'cut',
#   'fabric',
#   'apparel'],
#  ['repair',
#   'replac',
#   'upholsteri',
#   'household',
#   'furnitur',
#   'transport',
#   'vehicl'],
#  ['textil', 'apparel', 'furnish', 'worker', 'list', 'separ'],
#  ['shape',
#   'assembl',
#   'wooden',
#   'articl',
#   'set',
#   'oper',
#   'varieti',
#   'woodwork',
#   'machin',
#   'power',
#   'saw',
#   'jointer',
#   'mortis',
#   'surfac',
#   'cut',
#   'shape',
#   'lumber',
#   'fabric',
#   'part',
#   'wood',
#   'product'],
#  ['finish',
#   'refinish',
#   'damag',
#   'worn',
#   'use',
#   'furnitur',
#   'new',
#   'high-grad',
#   'furnitur',
#   'specifi',
#   'color',
#   'finish'],
#  ['full-siz',
#   'scale',
#   'wooden',
#   'precis',
#   'model',
#   'product',
#   'wood',
#   'jig',
#   'builder',
#   'loft',
#   'worker'],
#  ['lay',
#   'construct',
#   'wooden',
#   'unit',
#   'section',
#   'pattern',
#   'use',
#   'form',
#   'sand',
#   'mold',
#   'cast'],
#  ['oper', 'tend', 'wood', 'saw', 'machin', 'oper', 'equip', 'lead', 'sawyer'],
#  ['oper',
#   'tend',
#   'woodwork',
#   'machin',
#   'drill',
#   'press',
#   'lath',
#   'shaper',
#   'router',
#   'sander',
#   'planer',
#   'wood',
#   'nail',
#   'machin',
#   'oper',
#   'equip'],
#  ['woodwork', 'list', 'separ'],
#  ['control',
#   'nuclear',
#   'reactor',
#   'control',
#   'rod',
#   'start',
#   'stop',
#   'equip',
#   'monitor',
#   'adjust',
#   'control',
#   'record',
#   'data',
#   'log',
#   'emerg',
#   'procedur',
#   'need',
#   'respond',
#   'abnorm',
#   'determin',
#   'caus',
#   'recommend',
#   'correct',
#   'action'],
#  ['regul', 'distribut', 'electr', 'steam'],
#  ['oper',
#   'maintain',
#   'machineri',
#   'generat',
#   'electr',
#   'power',
#   'auxiliari',
#   'equip',
#   'oper'],
#  ['maintain',
#   'stationari',
#   'engin',
#   'boiler',
#   'mechan',
#   'equip',
#   'provid',
#   'util',
#   'build',
#   'industri',
#   'process',
#   'equip',
#   'steam',
#   'engin',
#   'generat',
#   'motor',
#   'turbin',
#   'steam',
#   'boiler'],
#  ['control',
#   'entir',
#   'process',
#   'system',
#   'machin',
#   'often',
#   'use',
#   'control',
#   'board',
#   'transfer',
#   'treat',
#   'water',
#   'wastewat'],
#  ['oper', 'entir', 'chemic', 'process', 'system', 'machin'],
#  ['process',
#   'gas',
#   'util',
#   'compani',
#   'control',
#   'compressor',
#   'maintain',
#   'specifi',
#   'pressur',
#   'main',
#   'pipelin'],
#  ['control',
#   'petroleum',
#   'refin',
#   'process',
#   'unit',
#   'special',
#   'control',
#   'manifold',
#   'pump',
#   'system',
#   'gaug',
#   'test',
#   'oil',
#   'storag',
#   'tank',
#   'regul',
#   'flow',
#   'oil',
#   'pipelin'],
#  ['plant', 'system', 'oper', 'list', 'separ'],
#  ['measur',
#   'load',
#   'mix',
#   'process',
#   'refin',
#   'feedstock',
#   'addit',
#   'ferment',
#   'reaction',
#   'process',
#   'vessel',
#   'monitor',
#   'product',
#   'process',
#   'keep',
#   'record',
#   'plant',
#   'mainten',
#   'repair',
#   'safeti',
#   'inspect'],
#  ['oper',
#   'maintain',
#   'landfil',
#   'gas',
#   'collect',
#   'system',
#   'compon',
#   'environment',
#   'monitor',
#   'control',
#   'system'],
#  ['monitor', 'biomass', 'plant', 'activ', 'perform', 'mainten', 'need'],
#  ['control',
#   'activ',
#   'associ',
#   'hydropow',
#   'generat',
#   'plant',
#   'equip',
#   'turbin',
#   'pump',
#   'valv',
#   'gate',
#   'fan',
#   'electr',
#   'control',
#   'board',
#   'batteri',
#   'bank',
#   'equip',
#   'oper',
#   'perform',
#   'make',
#   'necessari',
#   'adjust',
#   'ensur',
#   'optim',
#   'perform',
#   'equip',
#   'mainten',
#   'repair',
#   'necessari'],
#  ['tend',
#   'equip',
#   'control',
#   'chemic',
#   'chang',
#   'reaction',
#   'process',
#   'industri',
#   'consum',
#   'product',
#   'use',
#   'includ',
#   'devulcan',
#   'steam-jacket',
#   'kettl',
#   'reactor',
#   'vessel'],
#  ['oper',
#   'tend',
#   'continu',
#   'flow',
#   'vat-typ',
#   'equip',
#   'filter',
#   'press',
#   'shaker',
#   'screen',
#   'centrifug',
#   'condens',
#   'tube',
#   'precipit',
#   'ferment',
#   'evapor',
#   'tank',
#   'scrub',
#   'tower',
#   'batch',
#   'still',
#   'machin',
#   'extract',
#   'sort',
#   'separ',
#   'liquid',
#   'gase',
#   'solid',
#   'materi',
#   'recov',
#   'refin',
#   'product',
#   'dairi',
#   'process',
#   'equip',
#   'oper'],
#  ['oper',
#   'tend',
#   'machin',
#   'crush',
#   'grind',
#   'polish',
#   'materi',
#   'coal',
#   'glass',
#   'grain',
#   'stone',
#   'food',
#   'rubber'],
#  ['sand',
#   'polish',
#   'use',
#   'hand',
#   'tool',
#   'hand-held',
#   'power',
#   'tool',
#   'varieti',
#   'metal',
#   'wood',
#   'stone',
#   'clay',
#   'plastic',
#   'glass',
#   'object',
#   'chipper',
#   'buffer',
#   'finish'],
#  ['oper',
#   'tend',
#   'machin',
#   'mix',
#   'blend',
#   'materi',
#   'chemic',
#   'tobacco',
#   'liquid',
#   'color',
#   'pigment',
#   'explos',
#   'ingredi'],
#  ['hand',
#   'tool',
#   'hand-held',
#   'power',
#   'tool',
#   'cut',
#   'trim',
#   'varieti',
#   'manufactur',
#   'item',
#   'carpet',
#   'fabric',
#   'stone',
#   'glass',
#   'rubber'],
#  ...]

# %%
#create a Gensim dictionary from the texts
dictionary = corpora.Dictionary(texts)

#remove extremes (similar to the min/max df step used when creating the tf-idf matrix)
dictionary.filter_extremes(no_below=1, no_above=0.8)

#convert the dictionary to a bag of words corpus for reference
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
# %time lda = models.LdaMulticore(corpus, num_topics=100, id2word=dictionary, chunksize=10000, passes=100)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\ldamodel.py:802: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# Wall time: 4min 23s

# %%
lda.show_topics()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a238bd03d590> in <module>()
# ----> 1 lda.show_topics()
#
# NameError: name 'lda' is not defined

# %%
topics_matrix = lda.show_topics(formatted=False, num_words=20)
topics_matrix = np.array(topics_matrix)

topic_words = topics_matrix[:,:,1]
for i in topic_words:
    print([str(word) for word in i])
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-c9f79ff99053> in <module>()
#       1 topics_matrix = lda.show_topics(formatted=False, num_words=20)
# ----> 2 topics_matrix = np.array(topics_matrix)
#       3
#       4 topic_words = topics_matrix[:,:,1]
#       5 for i in topic_words:
#
# NameError: name 'np' is not defined
